# %% [markdown]
# <a href="https://colab.research.google.com/github/MOOwuttichai/BSC_DPDM2023/blob/main/%E0%B8%BABERT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertModel, AdamW, get_linear_schedule_with_warmup
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd

# %%
df = pd.read_csv("/content/Data_model.csv")
labels = []
for sentiment in df['label']:
  if sentiment == "เล่าประสบการณ์ (tell experience)":
    labels.append(1) #เล่าประสบการณ์ (tell experience)
  elif sentiment == "คำถาม (Question)":
    labels.append(2) #ไม่มีประโยชน์/ไม่สำคัญ (useless/unimportant)
  else:
    labels.append(0)
df['label_num'] = labels

# %%
train_df_E, test_df_E = train_test_split(df, test_size=0.3, random_state=42) # 70/30 split, random_state for reproducibility
print("Training set size:", len(train_df_E))
print("Testing set size:", len(test_df_E))
# Out:
# Training set size: 2168
# Testing set size: 930

# %%
# prompt: ช่วยเเก้ไข Imbalance ของข้อมูล df โดยที่ x คือคอลัม comments, y คือคอลัม label โดยใช้ imblearn

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler

# Separate features (X) and target (y)
X = train_df_E['comments'].values.reshape(-1, 1)  # Reshape for imblearn
y = train_df_E['label_num']

# Choose either oversampling or undersampling
# Oversampling:
oversampler = RandomOverSampler(random_state=42)
X_resampled, y_resampled = oversampler.fit_resample(X, y)

# # Undersampling:
# undersampler = RandomUnderSampler(random_state=42)
# X_resampled, y_resampled = undersampler.fit_resample(X, y)

# Create a new DataFrame with the resampled data
df_resampled = pd.DataFrame({'comments': X_resampled.flatten(), 'label': y_resampled})

# Now use df_resampled instead of df for training
texts = df_resampled['comments'].tolist()
labels = df_resampled['label'].tolist()
print(len(texts))
print(len(labels))
# Out:
# 4701
# 4701

# %%
df_resampled
# Out:
#                                                comments  label
# 0     คุณป้ามะเร็งลำไส้ใหญ่ เริ่มผิดปกติมีเลือดซึมออ...      1
# 1                                       Phonpin Mongkon      0
# 2                  ขอแชร์นะครับ ได้รับความรู้ดีมากๆครับ      0
# 3                                          Sopa Jadurai      0
# 4                                   Somkiat Suksongkram      0
# ...                                                 ...    ...
# 4696  มาหาข้อมูลว่าเสี่ยงมะเร็งตับไหม สูงทุกปีตรวจล่...      2
# 4697  สอบถามค่ะเรามีอาการเหมือนท้องผูกเวลาถ่ายท้องยา...      2
# 4698  ตรวจยังไงให้เจอเป๊ะๆ​ ไปทีไรปกติทุกที​ สมัยก่อ...      2
# 4699  วัดน้ำตาลปลายนิ้ว 143 ถือว่าสูงมากใช่ไหมฮะ ต้อ...      2
# 4700  อันนี้ไม่รู้จริงๆนะคะ เราไม่สามารถตรวจครั้งแรก...      2
#
# [4701 rows x 2 columns]

# %%
# train_texts, val_texts, train_labels, val_labels = train_test_split(texts, labels, test_size=0.3, random_state=42)

# %%
# prompt: ช่วยเเปลงข้อมูลใน list จาก str เป็น int

# Assuming 'labels' is a list of strings representing integers

# %%
set(labels)
# Out:
# {0, 1, 2}

# %%
class TextClassificationDataset(Dataset):
  def __init__(self, texts, labels, tokenizer, max_length):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length
  def __len__(self):
      return len(self.texts)
  def __getitem__(self, idx):
      text = self.texts[idx]
      label = self.labels[idx]
      encoding = self.tokenizer(text, return_tensors='pt', max_length=self.max_length, padding='max_length', truncation=True)
      return {'input_ids': encoding['input_ids'].flatten(), 'attention_mask': encoding['attention_mask'].flatten(), 'label': torch.tensor(label)}

# %%
class BERTClassifier(nn.Module):
  def __init__(self, bert_model_name, num_classes):
        super(BERTClassifier, self).__init__()
        self.bert = BertModel.from_pretrained(bert_model_name)
        self.dropout = nn.Dropout(0.1)
        self.fc = nn.Linear(self.bert.config.hidden_size, num_classes)
  def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output
        x = self.dropout(pooled_output)
        logits = self.fc(x)
        return logits

# %%
def train(model, data_loader, optimizer, scheduler, device):
    model.train()
    for batch in data_loader:
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        loss = nn.CrossEntropyLoss()(outputs, labels)
        loss.backward()
        optimizer.step()
        scheduler.step()

# %%
def evaluate(model, data_loader, device):
    model.eval()
    predictions = []
    actual_labels = []
    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            _, preds = torch.max(outputs, dim=1)
            predictions.extend(preds.cpu().tolist())
            actual_labels.extend(labels.cpu().tolist())
    return accuracy_score(actual_labels, predictions), classification_report(actual_labels, predictions)

# %%
def predict_sentiment(text, model, tokenizer, device, max_length=128):
    model.eval()
    encoding = tokenizer(text, return_tensors='pt', max_length=max_length, padding='max_length', truncation=True)
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        _, preds = torch.max(outputs, dim=1)
    if preds.item() == 1:
      L = "เล่าประสบการณ์ (tell experience)"
    elif preds.item() == 2:
      L = "คำถาม (Question)"
    else:
      L = "ไม่มีประโยชน์/ไม่สำคัญ (useless/unimportant)"
    return L

# %%
# Set up parameters
bert_model_name = 'airesearch/wangchanberta-base-att-spm-uncased'
num_classes = 3
max_length = 512
batch_size = 16
num_epochs = 10
learning_rate = 2e-5

# %%
train_texts=texts
train_labels=labels
val_texts = test_df_E['comments'].tolist()
val_labels = test_df_E['label_num'].tolist()

# %%
train_texts
# Out:
# ['คุณป้ามะเร็งลำไส้ใหญ่ เริ่มผิดปกติมีเลือดซึมออกมาทางทวารหนัก แต่ไปคิดว่าคงเป็นจากการถ่ายท้องเลยเป็นแผลหรือริดสีดวง ต่อมาเลือดไหลเยอะขึ้นตัวเริ่มซีดเหลืองเลยไปตรวจ เจอมะเร็งลำไส้ใหญ่ระยะ 3 ลามไปต่อน้ำเหลือง เริ่มฉายแสงคุณป้าเริ่มซูบผอมเบื่ออาหาร มีคนเอายาลูกกลอนมาให้ป้าทานหลังทานอาการดีขึ้นทานอาหารได้ ผิวจากเหลืองเริ่มชมพู มีเนื้อหนังขึ้น แกเลยทานต่อเรื่อยๆ ห้ามแล้วก็ไม่เชื่อ',
#  'Phonpin Mongkon',
#  'ขอแชร์นะครับ ได้รับความรู้ดีมากๆครับ',
#  'Sopa Jadurai',
#  'Somkiat Suksongkram',
#  'Chatchai Siliputthaivun',
#  'ดิฉันเป็นมะเร็งเต้านมระยะที่ 1 ขนาด 0.8 cm ดิฉันเป็นคนที่จะตรวจคลำเต้านมหลังอาบน้ำเกือบทุกวันตั้งแต่อายุ 35 ปี พอมีอะไรผิดปกติก็รีบไปหาหมอ คุณหมอบอกว่า คนไข้คลำเจอได้ยังไง ขนาดหมอยังคลำไม่เจอเลย ผลตรวจก็แจ๊คพอตค่ะ เมมโมแกรม อัลตราซาวน์ ตรวจชิ้นเนื้อ สร... ดูเพิ่มเติม',
#  'กินเก่งจัว',
#  'ก่อนหน้านี้ รู้สึกตัวเอง เพลียง่าย แล้วมาคลำเจอก้อนที่เต้านมค่ะ',
#  'ปี63เป็นมะเร็งรังไข่ค่ะระยะ1C อาการ ท้องโต ตอนแรกคิดว่าหน้าท้อง มีไข้ต่ำๆตอนหัวค่ำตลอดแทบทุกวัน ท้องแข็ง ปวดบิด เลยหาหมอถึงตรวจเจอค่ะ ตอนนี้รักษาครบ ติดตามทุก6เดือนค่ะ',
#  'คุณพ่อเป็นมะเร็งตับค่ะ อาการแรกๆแน่นเหมือนเป็นกรดไหลย้อน ไปหาหมอทีไรให้ยากินบ้างฉีดยาบ้างเกือบปี คนสูงอายุเราก้อคิดว่าคงอาหารไม่ย่อย ปลายปีมีอาการไข้ เป็นๆหายๆสลับกันทั้งเดือน ผอมลง เลยไปขอร้องให้หมอตรวจเพราะรู้สึกผิดปกติ เริ่มมีอาการตัวเหลือง ผลตรวจ ค... ดูเพิ่มเติม',
#  'พ่อเป็นมะเร็งลำไส้ เมื่อช่วงก.ค.ปี 63 พ่อปวดท้องแบบผิดปกติเลยไปรพ. หมอตรวจเจอค่าบางอย่างผิดปกติและให้แอดมิทนอนคืนนั้น ตอนเช้ารีบผ่าตัดด่วนหมอตัดก้อนเนื้อในลำไส้ออกพ่อต้องเจาะถุงขับถ่ายทางหน้าท้อง  หมอบอกว่าตัดออกแล้วแต่มันอาจจะแพร่กระจายไปส่วนอืืน... ดูเพิ่มเติม',
#  'Thana Tos',
#  'อาการมะเร็งปากมดลูกเป็นยังไงบ้างค่ะ คือตอนนี้กำลังสงสัยตัวเองค่ะ',
#  'Anurat Chanaka อ่านดูแม่',
#  'พนิดา อ่อนลา',
#  'กำไรฟาร์มสุข หนึ่ง',
#  'Aun Tra',
#  'รัอนตัวมากคะ',
#  'ย๊ากชูใจจจจจจ น๊าจ๊าา',
#  'Sirinat Bergsawangwong',
#  'Aomaim Kanchana',
#  'Pawat Akaraphanth',
#  'เป็นประโยชน์มากๆเลยค่ะ ขอบคุณทุกๆท่านนะคะที่แบ่งปันข้อมูลที่เป็นประโยชน์เพื่อเป็นเคสศึกษาต่อไป',
#  'พี่ติแทรกมาหมดแล้ว5โรคพอจะมีวิธีไหนที่จะลดลงไหมค่ะขอความรู้หน่อยค่ะขอบคุณนะค่ะ',
#  'ถูกแล้วที่จำกัดพฤติกรรมการกินค่ะ เพราะเด็กอ้วนไม่ใช่เด็กสุขภาพดีแต่เป็นเด็กป่วย อยากเห็นน้องแข็งแรงยิ้มหวานหวานแบบสดใสแข็งแรง น้าาาพ่อกอล์ฟ',
#  'เราเป็น #มะเร็งเต้านม อายุยังน้อย คลำเจอก้อนเองตอนอายุ 28 แต่มาตรวจเอาตอนอายุ 30 ปี เพราะแม่ไล่ให้ไปตรวจ ',
#  'สวยแล้วยังฉลาดอีก พ่อแม่เลี้ยงดูดีมาก แล้วยังว่าง่ายที่พ่อแม่ว่าอะไรก็ฟัง คุณพ่อคุณแม่โชคดีที่ได้ลูกคนนี้',
#  'เป็นประโยชน์มากๆ ค่ะ ขอขอบคุณทุกท่านที่ร่วมแชร์ข้อมูลนะคะ ',
#  'Phetsai Thirasiripon',
#  'Sorawit Thongaek',
#  'Aye Nanat',
#  'Piyada Far Chumchingรอยยิ้ม กวีในสายลม',
#  'ตัวเราเองเป็นมะเร็งต่อมน้ำเหลืองค่ะ',
#  'Kolunya Chutimakorn',
#  '#มะเร็งตับระยะสุดท้าย ไม่ออกอาการอะไรเลยพึ่งมาออกอาการได้3เดือนทุกอย่างเร็วมาก พ่อเป็นมะเร็งตับค่ะอาการเริ่มแรกที่เห็นคือเริ่มไอไอเยอะไอบ่อยเป็นๆหายๆพอพอสักระยะเริ่มมีไข้เริ่มแน่นท้องจุกท้องไปหาหมอหมอบอกว่าพ่อเป็นตับแข็งทั้งๆที่พ่อเป็นคนไม่ค่อยกินแอลกอ... ดูเพิ่มเติม',
#  'คุณแม่เป็นมะเร็งที่ต่อมน้ำเหลืองชนิดนอนฮอดกิ้น Diffuse large B cell เริ่มแรกก่อนรู้ว่าเป็นมะเร็งชนิดนี้ มีอาการปวดหลังเป็นหายๆ ดิฉันเป็นลูกสาวซึ่งเป็นหมออายุรกรรมก็เข้าใจว่าปวดจากการยกของ เพราะคูณแม่ขายผ้าหลาที่เป็นม้วนใหญ่ๆ จึงเข้าใจว่าปวดจากการยกของห... ดูเพิ่มเติม',
#  'แม่หนูเป็นมะเร็งผิวหนังค่ะ ชนิดที่ไม่ลุกลาม คุณหมอทำการผ่าตัดชิ้นเนื้อบริเวณส่วนที่เป็นเชื้อมะเร็งออกหมดแล้ว แต่ต้องคอยสังเกตดูอาการ ดูแลชีวิตประจำวันนะคะ เพราะ มะเร็งผิวหนังสามารถเป็นได้ง่าย และสามารถเป็นได้อีก แม่ทำการตรวจตอนปี 65 ค่ะแล้วก็เป็นเชื้อม... ดูเพิ่มเติม',
#  'ขอบคุณความรู้จากทุกท่านนะคะ และขอเป็นกำลังใจให้ทุกคนที่ป่วย โชคดีและหายไวๆค่ะ',
#  'ขอบคุณค่ะ สำหรับข้อมูลดีๆ',
#  'เป็นอยู่ขณะนี้เลย',
#  'Onelaya Laya',
#  'ป๋าเป็นมะเร็งตับค่ะ',
#  'ตอนนี้คุณแม่เป็นผู้ป่วยมะเร็งลำไส้ค่ะ อาการของคุณแม่อยู่ระยะที่ 3A มีการติดต่อไปที่ต้อมน้ำเหลืองภายในกล้ามเนื้อส่วนลำไส้ แต่ยังไม่มีการลามออกไปอวัยวะภายนอกค่ะ ',
#  'นี้ก็เป็นแปลบๆเหมือนกันที่ห้วใจอยุ่ันก็เจ็บขึ้นมา',
#  'คุณยายอายุ 76 เป็นมะเร็งลิ้นครับ สงสารยายมาก เริ่มจากยายมีแผลเหมือนร้อนในแต่ไม่เจ็บไม่อะไร ยายก็นึกว่าเป็นแผลร้อนในปกติจนกระทั่งปล่อยไป จนอาการมาออกหน้าเริ่มบวมแล้ว เลยไปหาหมอคลินิค หมอคลินิคเห็นก็บอกให้คุณยายไปตัดชิ้นเนื้อตรวจที่โรงพยาบาล แม่เราก็เริ่... ดูเพิ่มเติม',
#  'Amp Fine Jetnarong Chail Pedmanee Pradidthan',
#  'อายุ68ปีไม่เคยตรวจมะเร็งปากมดลูกและพบเป็นมะเร็งมดลูกเมื่อ1/7/23โดยวิธีMRI ABDOMEN (UPPER+LOWER)ที่เกาหลีใต้เพราะเลือดออกมากับปัสสาวะ เลยไปตรวจพบเป็นก้อนมะเร็งกลางมดลูกมาตรวจต่อที่รพในไทยคือรพตำรวจ7/8/23และตีองตัดมดลูกปีองกันการลุกลามเมื่อ1/9/23ก้อนเนื้อ้ป๋นเกรด1-2',
#  'แม่เป็นเต้านมระยะสาม+ hurr2 ตัวร้ายสุดของมะเร็งเต้านมเลย เคยเมโมแกรมพบก้อนผังผืดปล่อยไว้จนมันโตตรวจปุ๊บแจ็คพอทเลย พ่อต่อมลูกหมากระยะสามตรวจเจอเพราะเห็นแม่เป็นเลยไปตรวจแจ็คพอตเป็นพร้อมกันเลย รักษาหายมาแปดปีแล้วทั้งสองท่านกับอาจารย์วรชัยที่รามา',
#  'อริสรา หนูแป้น สแน็กร่าเริง หนุกหนาน',
#  'ขอบคุณมากค่ะคุณหมอข้อมูลดีๆค่ะ',
#  'Kik Janthima',
#  'Laddawan Bell',
#  'Nongnew Neww อ่านนะขอบคุณทุกๆ ท่านที่มาแบ่งปันข้อมูลนะคะ และขอให้หายขาด ปราศจากโรคใดๆ ค่ะ',
#  'พึ่งได้ผลชิ้นเนื้อวันนี้ ว่าแม่เป็นมะเร็งปอด หมอไม่ได้แจ้งว่าเป็นระยะไหน บอกเเค่ว่าไม่ต้องกังวลรักษาได้ ขั้นตอนต่อไปรอนัดพบหมอเกี่ยวกับมะเร็ง แม่ไม่กินเหล้าไม่สูบบุหรี่ ไม่ค่อยกินเนื้อสัตว์ กินเเต่ผัก ก็ยังเป็น ตอนนี้ไม่รู้จะไปทางไหนดี อาการแม่ก็กินอะไรไม่ค่อยได้',
#  'ดีมากๆเลยครับ จะได้เป็นวิทยาทานให้คนอื่น พ่อกับแม่เป็นครูและบทเรียนให้ผม^เอาเรื่องของผมก่อนเลย แม่เป็นมะเร็งเต้านม ตอนอายุประมาณ 40 ตัดนมทิ้ง 1 ข้าง ผ่านไป 10 ปี ได้ปวดแขนไปหาหมอได้ประมาณ 1 ปี หมอก็หาว่ายกของหนัก สุดท้ายพอไปตรวจtcสแกน มะเร็งก็ได้ลาม... ดูเพิ่มเติม',
#  'Gift M Amara',
#  "Na Nat Fari Kawa II Herbara Binti Abdullah Rashaad Shaad Mu'min Kado",
#  'Apinut Pega จิ๋วอยุ่ในวัยจ้ำม่ำป่าวว',
#  'Ninew Ummมาแชร์ไๆ',
#  'Ploy Binsriเทอชั้นอยากนอน',
#  'พ่อเป็นมะเร็งลำไส้ ',
#  'Kankawin Aroonpong',
#  'ต้องตวรจแบบไหนเพราะเคยไปตวรจแล้วไม่เจอ',
#  'Taen Chatsuda มีประโยชน์',
#  'ขอบคุณมากคะ',
#  'เด็กบ้านนี้กินผักกับผลไม้ ไอติมบ้างเป็นครั้งคราว แต่ผักกับผลไม้นี่ต้องมีทุกวันทุกมื้อ กินจนจะเป็นหนอนใบไม้อยู่แล้ว เนื้อสัตว์ต้องของร้องให้กิน รูปร่างนี่ผอมสูง แต่คนที่เก็บกินเนื้อสัตว์อย่างอิแม่นี่ อ้วนจนจะกลิ้งได้อยู่แล้ว... ',
#  'พ่อผมเริ่มจากเจ็บท้อง ผอมลงเรื่อยๆ ตรวจ3-4 รพ. ตรวจไม่เจอจน ไปตรวจ รพ. เอกชน เจอแต่ก็ระยะ3-4ไปแล้ว ปวดท้อง กินข้าวไม่ได้ ไปคีโมที่ รพ.จุฬาดีมากครับ แต่พ่อไม่ไหวครับแกหยุดการรักษา แล้วก็จากไปงานสงบเมื่อ 29 เมษาปี 65 ครับ มะเร็งท่อน้ำดี',
#  'เป็นอยุ่ค่ะทานโคคิวเท็นประทังไว้ค่ะ',
#  'ทองยุ้น พรหมส่วน',
#  'Poppinz Chutharat',
#  'Andy Leung',
#  'ไม่มีกรรมพันธ์ุ ไม่สูบบุหรี่ ไม่ดื่มเหล้า ทำงานอยู่แต่ในบ้าน เปิดเครื่องฟอกอากาศ นอนหลับพักผ่อนดี นอนห้าทุ่ม ตื่นสิบ่โมง  ทานอาหารก็ปกติ ไม่ค่อยกินปิ้งย่างชาบู ไม่ทานอาหารเวฟ ชอบทานพวกปลาต้ม ผัก  ออกกำลังกายบ้างเล็กน้อย พอไปฉีดวัคชีนไฟเซอร์ พบก้อนที่คอ แต่ไม่โต พอเป็นโควิด ก้อนโต ตรวจว่าเป็นมะเร็ง แต่ยังหาไม่ได้ว่าเป็นมะเร็งอะไร ไม่มีอการอะไร นอกจาก ก้อนโต ไม่ไอ ไม่เลือดกำเดาไหล ไม่ปวดอะไรทั้งสิ้น จากนั้นก็โดนฉายแสง คีโม แต่ไม่ไหว ขอออกมา รักษาตามธรรมชาติ ผ่านไป ก้อนที่คอยุบ หายไปไหนไม่รู้แฟนทำctscanเจอเนื้องอกที่ต่อมหมวกไต เมื่อวานแจ้งว่าน่าจะเป็นมะเร็งต่องรีบผ่า เร็วก็ต้องผ่านอกเวลา  แฟนไม่มีอาการอะไรเลยที่เจอบังเอิญไปทำซีทีดูนิ่วในถุงน้ำดี  หมอบอกดูจากลักษณะก้อนจากรูปยังไม่ได้เอาชิ้นเนื้อมาตรวจอยากทราบว่าผ่าที่ไหนจะเร็ว',
#  'เป็นมะเร็งเต้านมค่ะ แรกเริ่มอยู่ๆรู้สึกว่าหน้าอกใหญ่ขึ้น',
#  'เป็นไข้นานไม่หายค่ะ',
#  'Theerasak Rooplek',
#  'อายุ 25 ปี เป็นมะเร็งต่อมน้ำเหลืองค่ะอาการก็คือ เหมือนคนหายใจไม่ออก กินอาหารกลืนไม่ค่อยลง ไอแห้งๆ ไอตลอดเวลา ปวดตามตัวตอนนอน เหงื่อออกมาก ปวดตามหลัง ตามไหล่ จนทนไม่ได้ ต้องไปนอนให้มอร์ฟีนตลอด จนกว่าจะไปเข้ากระบวนการเจาะชิ้นเนื้อ ทรมานเอาเรื่องค่ะ ',
#  'รักเดกอ้วน',
#  'พ่อของเราเป็นมะเร็งหลอดอาหารหรือคอสักอย่าง เหตุเกิดจากกินของร้อนมากๆๆๆกับสูดดมเศษเพชรเศษทอง เพราะพ่ออยู่ที่จีนทำงานโรงงานทองอากาศหนาวและเป็นวัฒนธรรมที่เคยชินไปแล้ว จุดเริ่มต้นคือเจ็บคอกลืนข้าวไม่ได้ จากนั้นก็ผ่าตัดคีโมฉายแสง จนเสียชีวิต',
#  'Chuanphit Kunthawaraporn เหมือนอ้วนเลย มุบมิบ ทั้งวัน',
#  'เจ็บยกแขนไม่ขึ้นค่ะ',
#  'คนในครอบครัวตรวจเจอมะเร็งโพรงจมูกรักษาโดยการฉายรังสี + คีโม ',
#  'ศัลย์ สหกิจรุ่งเรือง',
#  'สวัสดีจ้า',
#  'Sornsawon Chancharoen  ดูแลสุขภาพ',
#  'ช่างเชื่อมสแตนเลส  ตัดเหล็ก เชืีอมเหล็ก เชืีอมอาร์กอน แบบแทบไม่ใส่หน้ากากเลย ชอบบอกว่าร้อน  ไม่ถนัด อึดอัด  ชินแล้ว  … 3-4 เดือน ก่อนตรวจพบ  มีอาการไอนิดหน่อย มีไข้ต่ำๆ  ตกเดือนละ 1 อาทิตย์ แล้วก็หายไป วนอยู่แบบนี้ 3-4 เดือน มีเพลีย  บ่นว่าหนาว ในวันอา... ดูเพิ่มเติม',
#  'Kasima Takrudthieng',
#  'ขออนุญาตแชร์นะคะ',
#  'ผมเป็นผู้ป่วยมะเร็งปอดระยะสุดท้าย อยู่กับเจ้ามะเร็งมาราวๆ 5 ปีแล้วครับ  เริ่มมาจากอาการปวดที่สะบักซ้ายในช่วงเช้าและความเจ็บปวดได้เพิ่มขึ้นในช่วงบ่าย จนตอนเย็นหลังเลิกงานเลยไปหาหมอเพื่อหาสาเหตุว่าอาการปวดเกิดจากอะไร ผมแอดมิทอยู่ที่โรงพยาบาลราวๆ 5 วัน... ดูเพิ่มเติม',
#  'มะเร็งต่อมน้ำเหลือง ระยะ 2 ชนิด d ไม่ไช่ฮอตกิ้น ปี 65  ตรวจสุขภาพเจอ ก้อนอยู่หลังปอด ติดกับต่อมไทมัส  ( ct scan ) อาการก่อนที่สังเกตตัวเองตอนนั้น ที่พอมีบ้าง หายใจไม่ค่อยสะดวกตอนนอน  ตอนแลกคิดว่าตัวเองอ้วนเพราะด้วยน้ำหนักตัวเอง 89 สูง 174  มีเหงื่อซึมๆ... ดูเพิ่มเติม',
#  'Noey Ank ของดีเลย',
#  'Jane JanejiraBmint',
#  'แม่เป็นมะเร็งต่อมน้ำเหลือง (ไม่ทราบระยะ)แต่มีก้อนที่คอ ใหญ่ขึ้น และมีหลายก้อน ปวดจนนอนไม่ได้ ได้รับการผ่าตัดชิ้นเนื้อไปตรวจ ถึงเจอว่าเป็นมะเร็ง จากนั้น คีโม6ครั้ง ฉายแสง 23 ครั้ง ผ่านมา6ปีตอนนี้อาการขึ้นๆลงๆเจาะไขสันหลัง4ครั้ง ค่าเลือดสูงสุด 1.3ล้าน ต่... ดูเพิ่มเติม',
#  'Mintra Singharatanasuwan',
#  'สลี ตันติลาสน์',
#  'Patarapol Roongsireung',
#  'เป็นก้อนที่คอ ก้อนเล็กๆ เหมือนคนมีกระเดือก ไม่มีอาการอะไรเลยค่ะ ไม่เหมือนซักข้อที่จะเป็น ผลอัลตราซาว2รอบก็บอกว่าไม่ใช่เนื้อร้าย เจาะชิ้นเนื้อไปตรวจ2รอบ ผล100%เลยว่าไม่ใช่เนื้อร้าย แต่ไม่สบายใจเลยขอผ่าออก ผ่าออกมาหมอบอกไม่ใช่เนื้อร้ายแน่ๆ เพราะก้อนสวยไม่เหมือนเนื้อร้ายแม่แต่นิดเดียว หมอฟันธงเลยว่าไม่ใช่มะเร็งล้าน%  แต่พอฟังผลเป็นมะเร็งไทรอยด์ค่ะ หมอก็ตกใจ ทุกคนตกใจหมด หมอก็พูดแค่ว่า ซว..ชิปหา..',
#  'ตาเป็นมะเร็งกระเพาะอาหารระยะสุดท้ายค่ะอาการคือ เหมือนโรคกระเพาะธรรมดา ซื้อยามากินเองแต่ไม่หาย ไปโรงพยาบาลหมอ บอกว่าเป็นโรงกระเพาะอาหารได้ยามากินแต่ไม่หาย แต่อาหารท่านทรุดหนัก ตัวเหลือง ตาเหลือง น้ำหนักลงไว อ่อนเพลีย เบื่ออาหาร  พอพาไปอีกโรงพยาบาล หมอใ... ดูเพิ่มเติม',
#  'Warachaya Wongwaitaweewong',
#  'Myname Snovy Ople',
#  '#มะเร็งเต้านมระยะ3ไป4ค่ะ ไม่มีอาการอะไรเลย แต่เวลานอนหงายจะมีก้อนที่คลำเจอตั้งขึ้นเหมือนแป้งนม แล้วจะโตขึ้นเรื่อยๆส่วนตัวจากเหรียญบาทไปไข่ไก่ประมาณ3เดือนค่ะ แต่ก็ยังไม่มีอาการปวดหรือผิดปกติอะไรเลย ยังกินได้นอนหลับปกติค่ะ จนกระทั่งเข้าตรวจเพราะใหญ่ขึ้นเรื่อยๆค่ะ รักษาประมาณ8เดือนนิดๆจบการคีโม,ตัดเต้า,ฉายแสงครบค่ะ#มะเร็งเต้านมระยะ3ไป4ค่ะ ไม่มีอาการอะไรเลย แต่เวลานอนหงายจะมีก้อนที่คลำเจอตั้งขึ้นเหมือนแป้งนม แล้วจะโตขึ้นเรื่อยๆส่วนตัวจากเหรียญบาทไปไข่ไก่ประมาณ3เดือนค่ะ แต่ก็ยังไม่มีอาการปวดหรือผิดปกติอะไรเลย ยังกินได้นอนหลับปกติค่ะ จนกระทั่งเข้าตรวจเพราะใหญ่ขึ้นเ... ดูเพิ่มเติม',
#  'Spoy Spoy',
#  'Kanyarat Elf ความรู้เยอะดี',
#  'Parawatee Phaksriphan',
#  'อันนี้ประสบการณ์ตรง ตอนเด็กๆพ่อแม่ผมทำงานที่กรุงเทพ แล้วครอบครัวผมเป็นคนสุพรรณเลยฝากตายายเลี้ยง ตอนอยู่กับพ่อกับแม่ก็ผอมเป็นไม้เสียบผี ตัดภาพมาตอนอยู่กับตายาย มีอะไรเข้าปากได้ซัดหมด ขนมเอย ข้าวเอย เกลี้ยง.... #จากไม้เสียบผีกลายเป็นสัมภเวสีหิวโหย... ดูเพิ่มเติม',
#  'คุณแม่เรา ท่านอยู่ตจว. มีกรรมพันธ์ุมะเร็ง แต่ท่านทานอาหารชีวจิตมาตลอด กินผักกินปลาที่ปลูกเองบ้าง ซื้อเพื่อนบ้านบ้าง จนกลางปี 65 แม่มีอาการไอ ไอแห้งๆ มาตลอด 6 เดือน ติดตามอาการตลอด  จนทางรพ.ต้นสังกัดส่งเข้า CTscan ที่ตัวเมือง ถึงรู้ว่าเป็นมะเร็งปอด  และ... ดูเพิ่มเติม',
#  'โภชนาการที่สมบูรณ์ และถูกวิธี ช่วยทำให้เรา รูปร่างดี สุขภาพดี ลดไขมันสะสม และ ไขมันในช่องท้อง ที่ก่อให้เกิดโรคต่างๆ สามารถใช้หลักการลดไขมันที่ถูกวิธีขจัดไขมันที่ว่ามานี้ออกไปได้ค่ะ ยินดีให้คำแนะนำนะค่ะ',
#  'มีอาการร่างกายด้านซ้ายอ่อนแรงหลังฉีดวัคซีนโควิด19เข็ม3 มีอาการอยู่เป็นเดือนไม่หายเลยตัดสินใจไปตรวจร่างกาย กลัวเป็นอัมพาตชั่วคราว แต่พอหมอตรวจทุกอย่าง แล้วก็ท่าจะไม่แน่ใจสั่ง MRI ที่หัวทันที พบเนื้องอกขนาดใหญ่ด้านขวา หมอสั่งรอห้องผ่าตัดทันที  หมอบอกว่ามันเริ่มจากปอดไปขึ้นหัว ระยะ4 เลยค่ะ',
#  'แฟนมีอาการถ่ายไม่สุดถ่ายกะปิดกะปรอยมีเลือดออกมาเวลาถ่าย ไปหาหมอส่องกล้องตรวจชิ้นเนื้อและทีซีสแกนซ้ำอีกรอบ ผลออกมามะเร็งลำไส้ระยะ4ค่ะ ตอนนี้รักษาอยู่ให้คีโมเข็มที่4แล้วและผ่าตัดถ่ายทางหน้าท้อง กินข้าวไม่ค่อยได้ผอมลงทุกวันเลยค่ะ',
#  'จี้ไฟฟ้าหัวใจจากร.พ รามามา3ปีแล้วค่ะ',
#  'น้ำหนักลด ผิวคล้ำ หมออัลตร้าซาวด์เจอก้อนเนื้อที่ตับประมาณ 2 cm.กว่าแล้วทำการตรวจอย่างละเอียดแล้วเจอ ทำการรักษาทันทีคะ',
#  'คุณยายเป็นมะเร็งโพรงจมูกระยะ3 1ปีครึ่งหายขาด แต่พบว่ามะเร็งลามไปที่ก้านสมองทราบว่าเป็นระยะสุดท้ายก่อนยายเสีย1วีคค่ะ ',
#  'อย่างที่หมอแชร์ตลอดคือ เตรียมพร้อมไว้โดยโยนความเสี่ยงให้บริษัทประกัน ในวันที่เรายังแข็งแรงครับ ',
#  'ขอสอบถาม เรื่องมะเร็งปอด ระยะที่ 3-4การดูแลหรือบำรุงต่างๆ อาหาร ระยะเวลาที่เหลืออยู่ จากประสบการณ์ตรงของผู้ป่วย หรือจากญาติใกล้ชิดของผู้ป่วยค่ะ ขอบคุณล่างหน้ามากๆค่ะ',
#  'คลำเจอก้อนเล็กๆที่หน้าอกค่ะรีบไปโรงพยาบาล ตรวจเช็คเป็นมะเร็ง เต้านมขั้นที่1 ให้คีโม 4 ครั้ง ปัจจุบัน 2 ปีแล้วค่ะสุขภาพก็โอเครค่ะ',
#  'หน้ารักครับ',
#  'จะเชื่อหมอหรือเชื่อวิศวดีนะ',
#  'Nutto Nut',
#  'มีน ชนัญย์ชิดา',
#  'บางคนเป็นแบบไม่รู้ตัวกว่าจะตรวจเจอก็รักษาไม่ทันแล้ว ประสบการณ์จากคนใกล้ตัวค่ะ',
#  'พึ่งไปนอนรพ.อยู่สามวัน เริ่มมีอาการชีพจรเบา 40-50/นาที เมื่อเมย.นี้ ไม่มีอาการอื่น เมื่อวันที่9 นี้ตื่นมามีอาการเหมือนที่คุณหมอ ว่านี้ ทำEkg,อุลต้าซาว.ออกรพ.แพทย์เพิ่มยาลดความดัน,ยาไขมัน นัดEco แต่ทำไม่ได้ ความดันขึ้นสูง ก็ยังไม่รู้เลยค่ะว่าเป็นอย่างไร',
#  'Korrakrit OrprasertNook Suttida',
#  'เรณู หุ่นจันทร์',
#  'พ่อเป็นมะเร็งปอด  เริ่มแรกน้ำหนักจะลด มีอาการเหนื่อยง่าย หายใจลำบาก เพราะมีอาการน้ำท่วมปอด มีอาการไอ สาเหตุเกิดจาก แร่ใยหิน  เพราะมีอาชีพรับเหมาทำบ้านรื้อบ้าน แร่ใยหินจะอยู่ใน กระเบื้อง ฝ้า เวลาแตกหักจะมีเศษฝุ่นที่ป่นแร่ใยหินอยู่ อันตรายมาก',
#  'Kanjana Ratnoi',
#  'มะเร็งรังไข่ : คุณแม่ไม่เคยมีอาการแต่วันนึงแม่บอกท้องน้อยตึงกดไปเหมือนแข็งและมีอาการเหมือนคนท้องอืด ทุกอย่างเริ่มต้นจากตรงนี้ จากวันนั้นเราได้พบหมอรัฐบาลตามสิทธิ์ 30 บาท หมอให้ยาแก้ท้องอืดแล้วบอกขอเป็นแค่ท้องอืด ไม่มีการเอ็กซเรย์ไรทั้งสิ้น แต่แม่ไม่หายท้องแข็งและเริ่มปวดท้อง เราจึงพาแม่ไปรามาหมอบอกเจอก้อนส่งเข้าเครื่อง MRI  จากวันแรกที่พูดว่าท้องแข็งถึงวันผลMRi ออกแค่ 20 วัน สรุปคือมะเร็งรังไข่ระยะ 3 บวก ก้อนมะเร็งของแม่ขนาด 11 เซ็น และแม่เป็นประเภทร้ายแรง ผ่าแล้ว คีโมแล้ว แต่มะเร็งกลับมาภายใน 3 เดือน  ดื้อต่อคีโมและก้อนใหญ่ ตอนแม่จากไปก้อนใหญ่เท่าลูกฟุตบอลอยู่ที่ท้องแม่ เราเห็นแม่ทรมานมากๆ จนแม่จากไป  เราเลยอยากเตือนเพื่อนๆ ว่าหากพอมีกำลังทรัพย์ขอให้ทำการอุลตร้าซาวน์ช่องท้อง ราคาไม่เกิน 1 พัน ปีละครั้งก่ยังดี คุณจะเจอเลยว่ามีอะไรในท้องบ้าง จะได้รีบรักษาเพราะมะเร็งรังไข่ไม่แสดงอาการเลยจนกระทั้ง ระยะท้ายๆแล้ว',
#  'Sakaewan Khantarate',
#  'ขอบคุณทุกท่านที่กรุณาแชร์เพื่อเป็นวิทยาทานนะคะ',
#  'คุณยาย ปวดท้องคล้ายโรคกระเพาะ หาหมอมาตลอด หมอแจ้งว่าเป็นโรคกระเพาะมาตลอด ทานยา สุดท้ายท้องเสีย ปวดท้องมาก เข้า รพ. รอบนี้หมอตรวจเลือดพบว่า เม็ดเลือดขาวต่ำมาก แอดมิท หลายวัน และนัดสแกน+ตรวจชิ้นเนื้อ สุดท้ายพบว่าเป็นมะเร็ง กระเพาะอาหาร ระยะ3 ปัจจุบันท่านเสียชีวิตแล้วค่ะ',
#  'พบเซลส์มะเร็งปากมดลูกค่ะ\u200b ในช่วงอายุ\u200b40\u200bปี ในระยะเริ่มต้นค่ะ1.\u200bเนื่องจากตัวเองไม่เคยมีสิวค่ะ\u200b แต่มันเกิดสิวขึ้นที่ข้างแก้ม\u200b รักษาเท่าไหร่ก็หาย\u200b หาหมอสิว\u200b ก็ยังไม่หาย\u200b แต่มีแค่\u200b 3-4 เม็ดนะคะ\u200b เลยหาข้อมูลพบว่า\u200bสิวที่เกิดบริเวณข้างแก้มเกิดจากฮอร์โมน2.ในทุกๆ\u200b เช้าที่ตื่นขึ้นมา\u200b รู้สึกว่าภายในร่างกายร้อนมาก\u200b แค่ไม่ได้เป็นไข้นะคะ ประกอบกับเว้นจากการตรวจภายในมา\u200b3ปีครึ่ง\u200b  เห็นความผิดปกติในร่างกายค่ะ3.ประจำเดือนมาทุก\u200bๆ\u200b20\u200b วันค่ะพอไปตรวจภายใน\u200bก็พบว่า\u200bมีเซลส์มะเร็งค่ะ\u200b ก็ตรวจซ้ำ\u200bเพื่อเช็คว่า\u200bอยู่ในขั้นไหนค่ะ\u200b แล้วก็ทำการรักษาคุณหมอบอกว่า\u200bโชคดีมาก\u200b แทบจะ\u200b1\u200bในล้าน\u200b ที่พบอาการในเบื้องต้น\u200b เพราะส่วนใหญ่แล้ว\u200b มะเร็งปากมดลูก\u200b จะมีอาการในระยะที่\u200b 3-4\u200bแล้วค่ะ\u200b ทำการรักษาผ่าตัดแบบส่องกล้อง\u200b ตัดส่วนที่พบ\u200bทิ้ง\u200b ปัจจุบันติดตามอาการปีที่7ค่ะ\u200b อยากบอกว่าเราต้องรู้จักสังเกตุร่างกายตัวเองนะคะ\u200b อะไรที่ไม่ปกติ\u200b รีบไปหาหมอเลยค่ะ\u200b  อย่ามัวแต่กลัว',
#  'หายใจไม่อิ่ม แน่นหน้าอก เอ็กซ์เรย์ตรวจคลื่นหัวใจ...ปกติค่ะ ได้ยาลดกรดและเคลือบกระเพาะมา น่าจะเป็นกรดไหลย้อน',
#  'ไม่มีอาการอะไรเลยค่ะ ตอนตรวจพบ เพราะฉะนั้นตรวจโรคทุกปีดีกว่าค่ะ',
#  'ตาเป็นมะเร็งลำไส้ใหญ่ส่วนปลายครับ อาการคือ ขับถ่ายกะปิดกะปรอย ปวดไม่เป็นเวลา เผินๆเหมือนท้องเสียบ่อยเฉยๆ สำคัญคือมีเลือดปนครับ  ความโชคดีคือที่บ้านตัดสินใจให้แกไปส่องกล้อง เลยพบก้อนมะเร็งไว ขนาดยังไม่ใหศ่และไม่ลามไปอวัยวะอืนครับ ตัดลำไส้ส่วนนั้นไป 4 ปี... ดูเพิ่มเติม',
#  'ภรรยาบังเกิดเกล้าผมเองครับ เกิดกับคนในครอบครัว',
#  'Anpunn Khodchawat',
#  'พ่อแฟนเป็นโรคปอด รักษาไปๆมาตรวจเจอมะเร็งตับ ตอนนี้ผ่าตัดมา1ปีกว่าแล้วน้องชายเพื่อน 3ขวบ ฝากญาติเลี้ยง ญาติอาบน้ำให้คลำเจอก้อนที่ใต้รักแร้ ไปหาหมอเจอมะเร็ง ปัจจุบันน้องหายแล้ว',
#  'แชร์ประสบการณ์ตอนอายุ34ปีค่ะ เป็นเนื้องอกที่ผนังหน้าท้องทับเส้นประสาทขาข้างขวา(หมอบอกแบบนี้)อาการคือปวดท้องไม่มีสาเหตุเจ็บสุดบริเวรที่มีเนื้องอกเพราะผอมและสามารถจับเจอก้อนเนื้องอกที่หน้าท้องด้านขวามีอาการท้องผูกร่วมด้วยก่อนเจอก้อนเนื้องอกปวดท้องมาประจำ... ดูเพิ่มเติม',
#  'พรทิพย์ ไชยสุริยวิรัตน์',
#  'Warin Kat Warinrat ใช่แบบนี้มั้ย',
#  'คิม เข้มข้น',
#  'ModSuperone Is อ่านยาวๆ',
#  'คุณแม่เป็นมะเร็งปอดค่ะ ตรวจพบว่าเป็นจุดเล็กๆกระจายปี 57 ได้ทำการจี้และผ่าตัด 2 รอบค่ะ หมอเฝ้าดูอาการตลอด จนพบว่ามีจุดเล็กๆกระจายไปในส่วนทีไม่สามารถผ่าตัดได้ เลยเปลี่ยนเป็นการใช้ยามุ่งเป้าค่ะ ตอนที่ทานก็มีผลข้างเคียงอยู่ แต่มะเร็งก็ไม่ได้แพร่ไปไหน และแม... ดูเพิ่มเติม',
#  'ITua Rangsiman',
#  'ดีมาก Nam Manassanan',
#  'Sasi Khunsanong',
#  'น่ารัก',
#  'คุณพ่อเป็นมะเร็งต่อมลูกหมากค่ะ ถ้ามีอาการ ฉี่ขัด รู้สึกฉี่ไม่ปกติให้รีบไปพบแพทย์อย่าปล่อยทิ้งไว้นานค่ะ ถ้ารู้เร็ว ก็อาจจะไม่เป็นมะเร็ง  ถ้าเป็นมากอาการฉี่ขัดถึงขั้นฉี่ไม่ออกปวดค่ะ ตอนนี้คุณพ่อรักษาอยู่ค่ะ',
#  'NEi Pakjiraa จ้ำม่ำยังไงก็ร้ากกกกกก ',
#  'Panuwat Turongrueng',
#  'Sukanya Niamhom',
#  'พ่อของแม่เป็นมะเร็ง แม่ก็เป็นมะเร็งลำไส้ใหญ่ แบบนี้เราจะเป็นไหมค่ะ ',
#  'Jirabhorn AnanwattanakulChutiporn SOm ChobkhaiNOn Chobkhai ข้อมูล',
#  'Nada Natcha ไข่พะโล้ตัวแตก',
#  'แบบนี้ถือว่าปกติมั้ยครับคุณหมอ',
#  'Supattra Noonsie Yanika Wattanarueangchai',
#  'ไปออกกำลังกายก่อน',
#  'Puwit Sripituk',
#  'พ่อเป็นมะเร็งปอด อายุ 61 เป็นคนดื่มเหล้าสูบบุหรี่ อาการเริ่มแรกน้ำหนักลดลงเรื่อยๆ จนหนังติดกระดูก เบื่ออาหาร มีอาการปวดเมื่อยบ่อยๆ (คิดว่าปวดเมื่อยแบบคนมีอายุล่าสุดตรวจเลือดปกติดี)รักษาด้วยแพทย์แผนจีน กว่าจะรู้ตัวว่าเป็นมะเร็ง ตอนเริ่มเดินไปไม่ได้ ไปรักษาแพทย์แผนปัจจุบัน พบมะเร็งตรงขั้วปอด ระยะที่ 4มีอาการติดเชื้อในกระแสเลือดร่วมด้วยเป็นผู้ป่วยติดเตียงอัมพาตครึ่งท่อนล่างหลังจากรู้ว่าเป็นมะเร็ง มีชีวิตอยู่ได้เพียง 3เดือน',
#  'Suwan Sangnark',
#  'Saowalak Sangployมึงงงง',
#  'หลังจากฉีดวัคซีนครบเข็มที่สาม มีก้อนใต้รักแร้ คลำได้ไม่เจ็บ สองเดือนยังไม่ยุบ ก่อนโตขึ้นๆ เลยพบหมอ หมอให้ยาปฏิชีวนะมาทาน สองอาทิตย์ไม่ดีขึ้น เปลี่ยนหมอมาพบหมอศัลยกรรมขอผ่าก้อนมาตรวจเพราะที่ครอบครัวมีคนเคยเป็นมะเร็งเต้านม ผลฉีดสีออกมา ปรากฏเป็นมะเร็ง หม... ดูเพิ่มเติม',
#  'Jee มาอ่าน ดีๆ',
#  'พ่อเราเป็นมะเร็งปอดค่ะ เดิมทำงานอยู่ไซต์ก่อสร้าง ไม่เคยใส่แมส ไม่เคยตรวจสุขภาพ จู่ๆ ก็ไอเรื้อรัง ไปหาหมอคลินิค ได้แค่ยาแก้ไอมากิน จนกระทั่งไอเป็นเลือด ถึงได้ไปตรวจรพ. ตรวจปอดอีกที เป็นระยะที่4 ซึ่งไม่ทันแล้วค่ะ อยากให้ทุกคนเห็นความสำคัญของการตรวจสุขภาพ... ดูเพิ่มเติม',
#  'Sikkarin Pongsombat',
#  'คุณย่าเป็นมะเร็งลำไส้ มารู้อีกทีตอนระยะสุดท้าย อาการที่พบได้ในเวลาประมาณ1-2ปีก่อนหน้า เหมือนว่าย่าถ่ายไม่ค่อยได้ อาจารเหมือนคนท้องผูกค่ะ ออกทีละนิดละหน่อย กินข้าวไม่ตรงเวลาก็จะปวดท้อง เลยเวลาไม่ได้เลย กินเผ็ดก็แทบจะไม่ได้ อาการปวดท้องก็ปวดมาเรื่อยๆตลอด... ดูเพิ่มเติม',
#  'เป็นมะเร็งเต้านม ระยะ 2 ค่ะ ไม่มีอาการอะไร เจอจากการคลำแล้วเจอก้อนเนื้อค่ะ เป็นก้อนแข็งยาวเหมือนนิ้วโป้งมือ ยึดติดไม่ขยับ ไม่เจ็บค่ะ ไปหาคุณหมอคุณหมอทำการเจาะไปตรวจแต่เจาะไม่ได้อะไรเลยทำการผ่าตัดเล็กและส่งตรวจค่ะ (รพ ประจำจังหวัด) รักษาด้วยเคมีบำบัด 4 คอร์ส ฉายแสง 24 ครั้ง รักษาที่ศูนย์ศรีพัฒน์เชียงใหม่ค่ะ ผ่านมา 9 ปีแล้วยังไป follow up ทุกปีค่ะ ',
#  'จาก 160+/100+ ออกกำลังกาย ว่ายน้ำ วิ่ง ปั่นจักรยาน กระโดดเชือก โน่นนี่นั่น ควบคุมอาหารการกินนิดหน่อย ประมาณ 3 เดือน น้ำหนักลงไป ประมาณ 7 กิโลกรัม',
#  'เป็น #มะเร็งตับ ตอนอายุ 29 ปี  บอกก่อนว่า เมื่อก่อนทำงาน รพ.นอนน้อยอยู่แล้วขึ้นเวรลงเวร ขวงเวร ชอบกินจังก์ฟูด น้ำหวาน น้ำอัดลม  ทุกวันก็ว่าได้ ดื่มชาเป็นมากกว่าน้ำเปล่า ดื่มเหล้าบ้างครั่งคราวตอนพบปะสังสรรค์ ออกกำลังกายน้อย',
#  'Su Arunrat',
#  'Vichaitee Tee',
#  'มีการตรวจเพื่อเฝ้าระวังไหมครับ',
#  'เท่าที่อ่านมาสามหมื่นแปดพันอาการ',
#  'Nattaponn Kanthanaphipaya',
#  'คุณพ่อเป็นมะเร็งกระเพาะปัสสาวะค่ะ อายุ 52 ปี มีโรคประจำตัวคือ Hep-B อาชีพ ทำสวน อาจมีคลุกคลีกับยาฆ่าแมลงหรือยากำจัดวัชพืชบ้าง... ดูเพิ่มเติม',
#  'เหมือนโดเรมอนจริง',
#  'เคยเป็นตอนไม่ได้นอนหลายๆวัน ไปตรวจหมอบอกพักผ่อนไม่พอ หัวใจเลยเต้นผิดจังหวะ',
#  'นพรัตน์ เสรีรักษ์Nopparat SayreeruxSiripak Sayrerux',
#  'Plug Skunk Yuk',
#  'คุณตาอายุ 71 ปีเป็นมะเร็งต่อมลูกหมาก เริ่มมีอาการปวดฉี่บ่อยเวลากลางคืน และมีอาการฉี่ขัดเหมือนไม่สุด ไปตรวจสุขภาพประจำปีพบค่า PSA 25 ทำ MRI ตัดชิ้นเนื้อตรวจพบมะเร็งระยะเริ่มแรก ทำ bone scan ว่าแพร่ไปยังกระดูกหรือไม่ โชคดีที่ยังเป็นเฉพาะในต่อมลูกหมาก ผ่าตัดแล้วเรียบร้อยด้วยดี',
#  'คุณปู่เป็นมะเร็งลำไส้ ระยะที่ 3 ค่ะ ตรวจเจอตอนอายุ 78 ปี ',
#  'นิตยา โมเม ความรู้',
#  'PC Nune',
#  'Pimmada May Keeratiwattanusad',
#  'แม่เป็นมะเร็งลำไส้ตรวจพบระยะ2 สัญญาณการปวดคือเริ่มด้วยการปวดท้องอย่างรุนแรง กินไม่ได้นอนไม่หลับ',
#  'คุณแม่เป็นมะเร็งที่สมองค่ะ ก่อนหน้านี้คือมีอาการปวดหัวบ้างเป็นครั้งคราว ซึ่งท่านก็จะบอกว่าเป็นไมเกรน ทานยา นอนพักก็ดีขึ้น จนเรามาสังเกตว่าท่านน้ำหนักลดลงอย่างรวดเร็ว ไม่ค่อยทานอาหาร และเริ่มปวดตามแขน ขา ข้อมือ จึงพาไปตรวจและพบว่าเป็นมะเร็งที่สมองในระยะ... ดูเพิ่มเติม',
#  'แม่บ้าน อายุ 50 กว่าเพิ่งเสียไป จากมะเร็งปอด',
#  'นันทิยา โนนโพธิ์ Mn OishiMn อ่านเป็นความรุ้',
#  'ขอบคุณค่ะ',
#  'คุณพ่อเป็น “มะเร็งตับระยะสุดท้าย”เดินขึ้นรถไปโรงพยาบาลเอง(ด้วยการโดนบังคับจากลูก) พี่สาวขับไปส่งที่ รพ. พร้อมกับคำว่า “คืนนี้ป๊าไม่ค้างนะ” ด้วยอาการไม่มีแรง ตัวเหลือง ปวดท้อง เข้าฉุกเฉินทันที ทราบว่าเป็นมะเร็งตับในวันรุ่งขึ้น... ดูเพิ่มเติม',
#  'Toei Nichkhun มีประโยชน์',
#  'Siriya Saungsirimol',
#  'ตัวซีด ไม่มีแรง ปวดท้อง ถ่ายไม่ออก',
#  'ผมเป็นมะเร็งปอดระยะ 3b ครับ อายุผม 30 ปี มีก้อนในปอดซ้ายล่างข้างเดียว และกำลังแพร่ขึ้นด้านบน ไม่สามารถผ่าตัดได้ครับ พึ่งเจอเมื่อ สิงหา 66 นี้ครับ ',
#  'Aom Tum',
#  'ปวดสะโพกร้าวลงขา ชาตลอดเวลา เป็นลมบ่อย ไป รพ.หลายรอบหมอบอกกล้ามเนื้ออักเสบ เปลี่ยน รพ.หมอให้เจาะเลือดตรวจ ผลเลือดผิดปกติส่ง Mri เจอก้อนเนื้อที่กระดูกสันหลังมีการกระจายเล็กน้อย หมอให้ไป รพ.ที่ใช้สิทธิได้ เพราะอาจเสียค่าใช้จ่ายเยอะ เลยไป รพ.ที่ใช้สิทธิบอ... ดูเพิ่มเติม',
#  'ตัวซีด ผิวช้ำง่าย มะเร็งเม็ดเลือดขาวแบบฉับพลัน',
#  'คุณแม่ตรวจร่างกายประจำปีค่ะ แล้วเจอเนื้องอกในตับ ไม่ทีอาการอะไรค่ะเป็นไปได้ควรตรวจค่ะ',
#  'เพิ่งไปหาหมอหา เกินทั้งตัวบนตัวล่างขอแชร์ข้อมูลไว้ศึกษานะคะ ขอบคุณค่ะ',
#  'Jenphob Aungkasuwan',
#  'ปิยาณี มากพูลผล',
#  'Pear Khumsawad ชูใจจ้ำม่ำแล้วววว ',
#  'Jirapron Tosiri นาย ปราโมทย์ โมท โตศิริ',
#  'ไม่มีอาการอะไร แต่ทำแมมโมแกรมประจำปีค่ะ แล้วเจอหินปูนในท่อน้ำนม (ไม่สามารถคลำเจอว่าเป็นก้อนเลย)คุณหมอดูแล้วว่าลักษณะหินปูน มีหน้าตาไม่ปกติ จึงให้เจาะชิ้นเนื้อด้วยวิธี Stereotactic breast biopsy กับเครื่องแมมโมแกรม ค่ะพบว่าเป็นเนื้อร้าย (ระยะแรก)',
#  'ก่อนที่จะรู้ว่าเป็นมะเร็งเต้านมระยะ 3 ย้อนไปเมื่อหลายปีก่อนเป็นคนเครียดกับการงานทำงาน เครียดกับทุกๆอย่าง พักผ่อนไม่เพียงพอ นอนดึกมาก ชอบกินน้ำอัดลม ขนมห่อ แต่หลังๆ มาก็หันมากินคลีนกินผัก น้ำหนักตัวเกินคืออ้วน และหัวนมข้างซ้ายที่เป็นมะเร็งบอดมาตั้งเด็ก ที่ผ่านมาตั้งใจอยากไปตรวจมะเร็งเต้านมแต่ไม่มีเวลาไป ชอบนอนอ่านหนังสือในไอแพคและเอามาวางไว้ที่หน้าอก แล้วมันไปสะดุดก้อนตรงหน้าอกข้างซ้าย(ที่หัวนมบอด) เทียบกับอีกข้างมันแตกต่าง จนวันที่ 12/01/65 ตัดสินใจไปตรวจ หมอศัลยกรรมคลำบอกขอบเขตมันไม่สวย หมออัลตราซาวด์ให้ถามว่าอยากเจาะชิ้นไปตรวจเลยมั้ย เราตอบตกลงทันที หมอให้คิวแมมโปรแกรม 19/01/65 รู้ผลเย็นวันนั้นเลยว่าเป็นมะเร็งเต้านมระยะ 3 ชนิด Her2+ ลามต่อมน้ำเหลือง (หมอย้อมสีชิ้นเนื้อให้เลยเพราะเราใช้สิทธิข้าราชการ) คุยกับหมอเรื่องขั้นตอนการรักษาตัดสินใจว่าผ่าตัดทั้งเต้า ผ่าตัด 03/02/65 หลังจากนั้นคีโม 8 /ฉายแสง 25/ฉีดยามุ่งเป้า 1 ปี เข็มที่ 8/12 และกินยาต้านฯ 5 ปี เพิ่งกินได้ 1 เดือน ช่วงให้คีโมอาการข้างเคียงออกตามคู่มือที่อ่านเลยค่ะพยายามกินโปรตีนสู้ให้ได้ค่าผลเลือดผ่านทุกครั้ง ช่วงฉายแสงอาการข้างเคียงน้อยมากนับว่าโชคดีมากๆ เพราะพยายามปฏิบัติตัวตามหมอสั่งทุกอย่าง ตรวจหัวใจปกติ/ตรวจกระดูกไม่ลาม/ตรวจปอดไม่ลาม นี่ก็ถือว่าโชคดีอีกแล้ว แต่ก็ต้อง CT SCAN ทุก 3 เดือน 6 เดือน เพื่อตัดตามผลตามหมอบอก ผลจากการเลาะต่อมน้ำเหลืองก็ต้องหมั่นออกกำลังกายแขนข้างที่ผ่าตัด ผลข้างเคียงของคีโมยังทำให้รู้สึกชาปลายเท้าและผ่าเท้าแต่ก็ไม่กระทบกับการใช้ชีวิตประจำวัน เรายังขับรถพาตัวเองไปหาหมอได้ เพราะตั้งแต่วันแรกของการรักษาจนถึงทุกวันนี้ไปหาหมอคนเดียวได้แบบสบายๆ จากที่เคยเครียดกับทุกอย่างทุกเรื่องตั้งแต่รู้ว่ามีน้องมะเร็งมาอยู่ในร่างกาย เราร้องไห้วันเดียวคือวันแรกที่รู้ว่าเป็น หลังจากนั้นโรคได้เปลี่ยนเราจริงๆ เราคิดได้แบบค่อยๆ ปล่อยวางทุกข์ ถึงจะไม่เก่ง แต่เราค่อยๆ ทำมันทำได้จริงๆ นะ ใจเราสงบยอมรับกับความไม่แน่นอนของชีวิต ไม่โทษอดีต ไม่ห่วงใยอนาคต เพราะต้องอยู่กับปัจจุบันยอมรับกับสิ่งที่เกิดขึ้นแล้วให้ได้ รักษาตามขั้นตอนของคุณหมอและไปตามนัดทุกครั้ง อยู่กับน้องมะขอบคุณน้องฯ ที่เปลี่ยนให้เราหันมาดูแลสุขภาพและดูแลจิตใจของตัวเอง เราเชื่อมั่นว่าเมื่อใจสงบ รอยโรคก็จะสงบ สู้ไปด้วยกันนะคะ',
#  'เป็นมะเร็งไทรอยด์ค่ะ ไม่มีอาการอะไร แค่ทาครีมแล้วเหมือนมีก้อนที่คอ แต่อีกข้างไม่มี เลยลองไปหาเฉยๆ ตรวจที่โรงพยาบาลจุฬา ผลออกมามีก้อนเนื้อร้ายที่ต่อมไทรอยด์ค่ะ',
#  'ตัวเราเอง อายุ 27 ปีค่ะ เป็นมะเร็งต่อมน้ำเหลือง ระยะ 2 ก้อนเนื้อใหญ่ 8 ซม. ประเภท Hodgkin ก่อนเจอมีอาการไอเรื้อรัง และหายใจไม่ค่อยเต็มปอดค่ะ เวลาโดนลมแรงๆ หรือกลิ่นแรงๆ ก็จะไอไม่หยุดเลย น่าจะเพราะก้อนเนื้อที่เราเจออยู่ใกล้หลอดลม แอบทับปอดกับหัวใจนิดหน่อย แฟนเลยเริ่มหารายชื่อหมอเก่งๆ ของมะเร็ง ได้เจอกับคุณหมอศิระ เลาหทัย ส่งตัวเราจากโรงพยาบาลเอกชน มาโรงพยาบาลวชิรพยาบาลค่ะ หมอเก่งมากๆค่ะ ดูCT Scan แล้วรีบจัดการให้เราไปตัดชิ้นเนื้อ ส่งตรวจเลย หลังจากนั้น เราก็ทำตามคำแนะนำหมอตลอด เมื่อวานให้คีโมเข็มแรกแล้วค่ะ ยังไม่มีผลข้างเคียงอะไรมากมาย ตอนนี้แพทย์ที่ดูแลจะเป็นหมอโรคเลือด คือคุณหมอดุสิต จิตรเอื้อกุล อยากแนะนำให้ทุกคนสังเกตุตัวเองดีๆ เพราะถ้ายิ่งเจอเร็ว ได้รักษาเร็ว ก็มี% ดีขึ้นแน่นอนค่ะ เป็นกำลังใจให้ทุกคนเลยนะคะ',
#  'Kongpan Norarat',
#  'Punchida Limrattanasilp',
#  'เราจะรอ',
#  'แม่เป็นมะเร็งปอดค่ะ อาการเริ่มแรกคือมีอาการไอและะก็ไอเรื่อยๆมาตลอดประมาณ2เดือนไม่หายจนกระทั่งไปพบหมอเพื่อx-ray ดู ผลออกมาเป็นมะเร็งปอดระยะที่3 ก่อนหน้านี้แม่มีอาชีพขายของบนเเผงบนฟุตบาทจะเจอฝุ่นและะควันรถอยู่ตลอดและทำอาหารกับไม้ฝืน เป็นคนเลือกกินอาหารที... ดูเพิ่มเติม',
#  'เคยขอหมอตรวจ(หาเรื่อง)หมอบอกตรวจก็เจอ ทุกคนมีเชื้อมะเร็งอยู่ในตัวเลยไม่อยากกังวล ต้มใบมะกอกินไป555',
#  'สวัสดีค่ะ หนูเป็นมะเร็งรังไข่ระยะ3 อายุ27 พึ่งจบคอสคีโมมาได้3เดือน ไม่มีพันธุกรรมหรือกรรมพันธุ์มะเร็ง  ไม่เคยใช้ชีวิตที่มีความเสี่ยงจะเป็นมะเร็งได้เลย แต่เป็นเพราะเซลในร่างกายแบ่งตัวผิดปกติเองคุณหมอบอกว่ามะเร็งรังไข่ตรวจพบในระยะแรกเจอยากมากเพราะมันไม่... ดูเพิ่มเติม',
#  'Itp Poodomrong',
#  'Sank Natthapongพงษ์ธร ทิมประเสริฐ',
#  'คุณพ่อเป็นมะเร็งถุงน้ำดี(65ปี)ในวันที่ลูกชายคนเล็กจะรับปริญญา พ่อไปไม่ไหวท้องอืด ท้องเสีย ท้องป่อง ตัวเหลือง ตาเหลืองเดาไม่ยากตับแข็ง หมอรักษาแบบประคับประครอง... ดูเพิ่มเติม',
#  'แม่เป็นมะเร็งท่อน้ำดี ลามไปปอดค่ะ แม่ชอบดื่มเหล้าขาว วันละนิดละหน่อยแต่เกือบทุกวัน ทานยาชุด อาการเริ่มแรกที่ก่อนพาไปตรวจคือไอหนักมากค่ะ ไอแห้งๆ แม่เลยกินแต่ยาแก้ไอคิดว่าแพ้อากาศ ไม่คิดว่าแม่จะเป็นมะเร็งเพราะยายเสียด้วยโรคมะเร็งตับ หมอบอกว่าจะมีคนในครอบ... ดูเพิ่มเติม',
#  'ตอนอายุใกล้จะ 40ปีไม่เคยเป็นตกขาวมาก่อน เกิดมีตกขาวออกมาจากช่องคลอด เป็นน้ำๆ และออกมาเยอะ จนต้องเปลี่ยนชุดชั้นใน เป็นอยู่ 3 ครั้งเลยไปตรวจเพิ่มแพทย์สั่งตรวจมะเร็งปากมูดลูกและสั่ง CT scan เพิ่มผลตรวจไม่เป็นมะเร็งปากมดลูกแต่เป็นมะเร็งใน มดลูกข้างรังไข่แพทย์ส่งตัวมารักษาที่ โรงพยาบาลจุฬาลงกรณ์ ผ่าตัดรักษา เคมีบำบัด ฉายแสงฝั่งแร่ จบการรักษาทุกอย่างหายเป็นปกติค่ะไม่สูบบุหรี่\u200b แต่รับบุหรี่มือสองมาตลอด\u200b เป็นมะเร็งปอด\u200b ชนิด\u200b คาร์ซินอ\u200bยด์\u200bค่ะ\u200b ไม่มีอาการ\u200b ตรวจเจอเพราะที่ทำงานส่งไปตรวจสุขภาพ\u200b แล้วเจอจุด1จุดหมอเห็นผิดปกติเลยส่งไปทำCT\u200b scan ตรวจชิ้นเนื้อ\u200b ย้อมสี ฉีดสี\u200b แล้วก็ผ่าตัดปอดออกไปแล้วครึ่งนึงข้างซ้าย\u200b ปัจจุบัน\u200bติดตามผลทุก3-6เดือนค่ะ\u200b',
#  'Gunso Cool',
#  'นาย วิลาศ เพ็ชรสุข',
#  'จะดีมากเลยค่ะ ถ้าผู้ป่วยที่เป็นมะเร็งรักษาหาย แล้วไม่มีเชื้อมะเร็งอีก มาแชร์เป็นวิทยาทานในการดูแลตัวเอง เพื่อเป็นแนวทางในการใช้ชีวิตและเป็นกำลังใจให้ผู้ที่กำลังรักษาตัวอยู่ ให้ปฏิบัติตาม เพื่อจะได้มีชีวิตอยู่กับลูกหลานนานๆ (แม่สามีเป็นมะเร็งขั้นสุดท้ายแล้วรักษาหาย ทุกวันนี้ยังใช้ชีวิตปกติและไม่มีเชื้อมะเร็งอีกเลย) เป็นกำลังใจให้ผู้ป่วยและลูกหลานทุกคนนะคะ',
#  'Tinga S. Meezingtons',
#  'Rommani Jj',
#  'ติดตามด้วยค่ะ',
#  'Pipat Taweechaihouse',
#  'Kanchana Thiansawat เป็นประโยชน์มาก',
#  'Kannika Ang',
#  'Plernpit Tepsorn',
#  'มะเร็งมันไม่ใช่เป็นปุ๊บปับ มันใช้เวลาเพาะบ่ม นาน  กรรมพันธ์ก็สำคัญ',
#  'มีไข้ต่ำๆตอนเย็น-ค่ำท้องผูก',
#  'Mink Vetch',
#  'Panida Suaysom',
#  'นิยม คิมประสูตร',
#  'Wawajung Damrongtaveesak วัดให้หน่อยยยย',
#  'นายกสมาคม คนรักครอบครัว ไมค์ลองอ่านดูบางอาการเหมือนคล้ายๆเลย',
#  'Kritsada Unchana',
#  'Nisachon Suwandee',
#  'น่ารักมากกกน้องชูใจ',
#  'Ponsuang Ludeelerd',
#  'ขอบคุณครับผม.',
#  'แม่ตรวจเจอมะเร็งปี2554 ไม่มีอาการเจ็บปวดใดๆ แต่แม่เป็นคนชอบกินกาแฟ3in1มากๆ กินวันละ4-5ซอง ตอนนั้นเราวัยรุ่นห้ามเค้าไม่ได้ เค้าสูบบุหรีดื่มเหล้า คนในครอบครัว ชวด ปู่ ย่า ตา ยาย ไม่มีใครมีประวัติเป็นมะเร็ง ... ดูเพิ่มเติม',
#  'Chinnapat Sudcha น่าย้ากกกก',
#  'KP Tammajinda',
#  'วิเชียร ไชยสุวรรณ',
#  'อ่านแล้วใกล้เคียง..กะม๊า..เรื่องเป็นกรดไหลย้อน..นอนไม่หลับ..ตอนนี้กินยานอนหลับของหมอ',
#  'Kanyarugk Gosungnean',
#  'มะเร็งเต้านม นอนดึกนอนน้อย ของหวานจัดเต็มแป้งน้ำตาล ไวน์แอลกอฮอล เริ่มด้วย นิ่วถุงน้ำดีตัดออก 3-5ปี ไฮเปอร์ไทรอยด์ 3-5ปี ต่อด้วยมะเร็งเต้านม ตอนนี้ ลดน้ำตาลลดแป้ง เลิกแอลกอฮอล์ นอนขั้นต่ำ6 ชม ถุงน้ำดีเอาคืนไม่ได้... ดูเพิ่มเติม',
#  'อันนี้ดีอยู่นะ  อ่านแล้วกลายเป็นวิตกจริตเลย 55555 Suneerat Aumaim',
#  'ชอบการสื่อสารของขุ่นพ่อบ้านนี้มากค่ะ เพราะทุกสิ่งทุกอย่างที่เราใส่ใจ  ก็เพื่อเจ้าตัวเล็กจริงๆ',
#  'Wannakit Pora',
#  'ขอบคุณค่ะ',
#  'ป่วยบ่อย หน้ามืดบ่อยปวดท้อง จนเป็นลมบ่อย',
#  'อ้อยใจ คงคา',
#  'ภู ภูชิสส์ Surachat Jmc Michael Gray',
#  'สวัสดีค่ะขอบคุณข้อมูล ประสบการณ์ที่แชร์ค่ะโชคดี ขอให้ใด้รีบการรักษา ใด้ถูกต้องทันการ  ขอเป็นกำลังใจให้ทุกท่านค่ะขอบคุณมากค่ะท่าให้โอกาสติดตามค่ะ',
#  'TG CholoStyle',
#  'เคยแชร์แล้วครับมะเร็งปอดทั้งที่ไปสูบบุหรี่…ผมฉึดวัคซีนโควิดแล้วรู้สึกผิดปกติกลัวเป็นลิ่มเลือด จึงพบแพทย์เลยรู้ว่าเริ่มเป็นก่อนไปขั้วปอดซึ่งจะรักษายากขึ้นตรวจปอดทุกปีคงช่วยได้นะครับชัวร์ก่อนแชร์ เรื่องอาหารอะไรช่วยป้องกัน และอาหารเหมาะสมเมื่อเป็นแล้วครับ.',
#  'แบบนี้เป็นไงครับ',
#  'คุณยายอายุ 82 ปี พบเจอมะเร็งปอด ',
#  'พ่อเป็นมะเร็งหลอดลมและกระจายไปปอดค่ะ (เสียชีวิตในระยะเวลา 4 เดือน)',
#  'โพสนี้ดีมากๆ เลยค่ะ ขอแชร์แม่บุญธรรมเราบ้างค่ะ กรรมพันธุ์\u200bไม่มีใครเป็นมะเร็ง',
#  'คุณตาเป็นมะเร็งตับอ่อนค่ะ เกิดจากพฤติกรรม100% ไม่มีอาการอะไรเลย จนระยะสุดท้าย เริ่มป่วย มีไข้ ฉี่เป็นเลือด ปวดท้อง กินยารักษา3-4หมอก็ไม่พบมะเร็ง เพราะมะเร็งไปเกิดอยู่ด้วยหลังของตับ พบอีกทีคือลามไปทั่วร่างกายแล้ว คุณตาเหมือนคนปกติทุกอย่าง ไม่ตัวเหลือง ม... ดูเพิ่มเติม',
#  'Nut Boonkum',
#  'Nan WS Wiphada',
#  'Kawtom Kaewsai ',
#  'ขอเล่าเรื่องของคุณแม่เรานะคะ แม่เป็นมะเร็งโพรงมดลูกค่ะ ตอนนั้นแม่อายุ 40ปี ทางแม่ยังไม่มีใครเป็นมะเร็งค่ะ แม่เคยตรวจเจอก้อนเนื้อก่อนหน้าแต่เป็นเนื้องอกธรรมดา ต่อมามีอาการคือประจำเดือนเยอะ เยอะมากๆๆๆๆ แล้วเป็นทั้งเดือน บางเดือนหยุดแต่หยุดแค่ 2-3วันแล้ว... ดูเพิ่มเติม',
#  'ให้ใจ๋กินไปก่อน เดี๋ยวยืดเองนะ',
#  'Lickk Peerapat',
#  'ดีมากๆจริงๆค่ะ โพสต์นี้ เป็นวิทยาทานให้กับผู้คน และเป็นกำลังใจให้กับทุกๆท่านที่ป่วยด้วยนะคะ สำหรับคนที่ยังไม่ป่วยก้อจะได้ตระหนักรู้ถึงเวลาวันนี้ว่าโชคดีที่ไม่ป่วย',
#  'Marinee Sakonvaree',
#  'Rjingnew Siangwarn สาเหตุความกลมๆของลูกสาววว ^^',
#  'Jutarat Boui Kangruambut',
#  'เด็กกำลังจะยืดตัวสูงขึ้นค่ะ',
#  'รบกวนสอบถามผู้รู้พ่อเราอายุ71ตรวจเจอก็พบเป็นมะเร็งตับระยะ4เลยก่อนหน้านี้ไม่มีอาการใดๆแต่พอช่วงหลังพ่อเหม็นอาหารทานอะไรไม่ได้เลยนอกจากโปรตีนมีวิธีไหนบ้างไหมค่ะรืออาการมะเร็งตับจะมีอาการแบบนี้',
#  'อุจาระเปลี่ยนสี ไม่มีแรง ไม่มีเสียงไม่ต้องไปตรวจรักษาทันทีปวดศรีษะหรือเป็นไข้เป็นปี',
#  'Ava Chan มาอ่านคอมเม้นเลย',
#  'แม่เป็นมะเร็งปอดระยะ 4 ค่ะแม่ไม่สูบบุหรี่ และไม่มีคนในบ้านสูบบุหรี่เลย ก่อนหน้านี้แม่สุขภาพร่างกายแข็งแรงมาก ทานอาหารมีประโยชน์ และไม่ได้ทำงานในพื้นที่เสี่ยงมลพิษเลยค่ะ อาการเริ่มแรกก่อนตรวจเจอมะเร็ง คือ แม่มีอาการขาบวม และปวดขามากๆค่ะ ไปหาหมอที่ รพ.... ดูเพิ่มเติม',
#  'Jiraporn Prim',
#  'มะเร็งเต้านม ระยะ 0',
#  'Gaty Guitaa กินอาหารที่มีประโยชน์นะคะ',
#  'Bright Posuwan',
#  "Nim'm Panarat",
#  'Ton Wachirawit',
#  'เหมือนที่บ้านเลยคะ..555',
#  '#มะเร็งตับ แม่ตรวจพบว่าเป็นมะเร็งตับระยะสุดท้ายเมื่อกุมภาพันธ์ 2565 แต่เป็นโรคตับแข็งมานานมากกว่า 10 ปี ไปหาหมอบ้าง ติดตามอาการไม่ต่อเนื่อง และมีโรคประจำตัวคือเบาหวานและความดัน...ตรวจพบแล้วรักษาไม่ได้เนื่่องจากอายุเยอะ 72 ปี และเม็ดเลือดขาวมีน้อย ร่างกายอาจจะสู้ไม่ไหว แม่อยู่ได้ประมาณ 1 ปีกว่า อาการทรุดลงเนื่องจากก้อนมะเร็งแตก อาการคือ ท้องบวมโต เจาะน้ำออกมาได้ 4 ลิตรปนเลือด...นอน รพ. 9 คืนและกลับออกมาพักรักษาตัวที่บ้านได้เดือนกว่า แม่ก็เสียชีวิตลง',
#  'ป้าเกรซที่ป่วย เพราะเขาเป็นช่างผมค่ะ สมัยก่อน ทำเคมีทุกอย่าง ป้าไม่เคยสวมถุงมือ และ mask เพิ่งจะมาสวม 4-5 ปีนี้เองค่ะ ... ดูเพิ่มเติม',
#  'รออ่านค่า',
#  'Joy Charu-amornchit มาๆๆ',
#  'Nîthïkøŕň Tăśâñğ น่าสนใจมาก',
#  'คุณพ่อเป็นมะเร็งปอด ไม่มีอาการอะไรเลย บ่นว่าปวดแถวๆ บั่นเอวช่วงอากาศหนาวๆ จนวันหนึ่งที่แกปิดประตูบ้านขึ้นรถแล้วขึ้นมาด้วยอาการหอบเหนื่อย เลยให้ไปตรวจร่างกาย (ปกติตรวจสุขภาพที่คลินิคที่รับยาเบาหวาน) สรุปว่าเป็นมะเร็งปอด ลุกลามไปที่กระดูก จนเสียชีวิต ',
#  'น่ารักค่ะ',
#  'คุณพ่อเป็นมะเร็งตับค่ะ อาการคือปวดท้องถ่ายไม่ออก พอถ่ายออกก็ถ่ายเป็นเลือด ก็คิดว่าท้องผูก เลยไปหาหมอที่ รพ.ค่ะ หมอให้ส่องกล้อง นอนรองดน้ำงดอาหารประมาณ 9วัน พอส่องกล้องเสร็จ หมอก็บอกมีเนื้องอกที่ตับ ตอนนั้นตับเริ่มฮีลแล้ว เราไม่รีรอ พาส่ง รพ.จุฬา คนเยอะ... ดูเพิ่มเติม',
#  'Punnit Kunjara Pinyakk Jirapinya นก ภควัฒน์ กุญชร',
#  'ปวดท้องมีไข้',
#  'Thanatchporn Mana',
#  'พ่อเสียไปเมื่อปี 63 เป็นมะเร็งปอดตั้งแต่จำความได้ แกไม่เคยเข้า โรงพยาบาลเลย ในด้านการหาหมอ ปวดหัวกินยาพารา คือซื้อยาทานเอง ตลอด อาการที่มีคือไอมานานมาก เกิน 10ปี  มีเสมหะ จนปี 62 แก ไอจนเลือดออก พาไปหาหมอ ตรวจพบก้อนเนื้อในปอด และเจอว่าเป็นมะเร็งระยะที่... ดูเพิ่มเติม',
#  'แม่ผมเป็นมะเร็งเม็ดเลือดขาวเฉียบพลันชนิดมัยอิลอยด์ (Acute Myeloid Leukemia – AML) ตรวจพบต้นๆเดือน ยังไม่ทันให้คีโมหรือยา ประมาณ 21 วัน แม่ก็จากไปอย่างสงบ',
#  'คุณพ่อเป็น มะเร็งหลังโพรงจมูก ระยะ3 ครับเจอเพราะมีก้อนเนื้อปูดขึ้นที่คอ ช่วงรอคิวรักษาด้วยการฉายแสงและคีโม ได้ทานเซซามินเป็นเวลา1เดือนเศษๆ ก่อนรักษาตรวจซ้ำอีกทีก้อนมะเร็งยุบตัวฝ่อ แต่ก็เข้ารับการรักษาตามปกติ แต่คีโมไม่ครบครับ คุณพ่อทนไม่ไหว... ดูเพิ่มเติม',
#  'ก้อนที่เต้านม ผญ. ทุกคนที่มีก้อนรู้สึกว่าอยู่กับมันมาตลอดได้ บางช่วงอาจหายไป บางช่วงเกิดขึ้นตามรอบเดือน แต่ไม่เจ็บมากจนผิดปกติ ... เราเป็นคนทำงานหนักมาตลอดเพราะภาระเยอะ อายุช่วงหลัง 40 ทำงานหนักมาก ๆ 3 ปี  ใช้ทั้งร่างกายและจิดใจ คลอดลูกเลี้ยงลูกกลางคืน... ดูเพิ่มเติม',
#  'คนเป็นมะเร็งกันเยอะ อายุน้อยก็เพียบ',
#  'Pattanapon Hangboonsukkul',
#  '..พ่อมีอาการเหนื่อยหอบง่ายมากๆ แน่นท้อง อืดท้อง บ้านหมุน กินอะไรก็แน่นท้อง  หายใจๆไม่ทั่วท้อง  สรุป พ่อเป็นมะเร็งตับ  มาจากปอดลามไปตับ ลามไปถุงน้ำดี ตรวจเจอระยะสุดท้าย หมอบอกอยุ่ได้ 3-6 เดือน  รักษาตามอาการ สุดท้ายขึ้นสมอง รักษาที่ รพ ได้ 2 คืน พ่อก็จ... ดูเพิ่มเติม',
#  'Parn Suphanyada',
#  'อากง 80 ปีอยู่ดีๆ ก็เสียงแหบ พอไปตรวจ พบเป็นมะเร็งปอดระยะ 1 ดูแลอาการได้ 2 ปีสุดท้ายก็เสียชีวิตครับ',
#  'สวัสดีค่ะคุณหมอเคยเห็นมาหลายเคสแล้วค่ะเขาบอกเขายังเด็กอยู่สุดท้ายไปเลยค่ะ',
#  'ขอบคุณนะคะ',
#  'แม่เป็นมะเร็งหลอดอาหารค่ะ ก่อนหน้านี้เป็นโรคกระเพราะ กินข้าวไม่ตรงเวลา พอมีเวลาก็จะรีบๆกินไม่เคี้ยวให้ดีก่อน อาการก่อนตรวจเจอมะเร็ง น้ำหนักลด กินได้น้อย กลืนลำบาก เอายาแก้กรดไหลย้อนของดาราคนหนึ่งมากิน เหมือนจะดีขึ้น หลังจากกินได้3 เดือนก็กลับมาเป็นใหม่ เลยตัดสินใจไปเอายา รพ เจอหมอจับตรวจ เจอแจ๊คพอตเลยจ้า ',
#  'ทำไมตอนเด็กเราไม่ยืนบนเก้าอี้นะ เรวัต ทองโต เก่ง ประชาชนของในหลวง ครุ่นคริส',
#  'คลำเจอก้อนที่เต้านมค่ะ',
#  'Tataff Taf',
#  'คุณแม่ของผมเป็นมะเร็งเต้านมระยะที่ 2 ครับ อาการเริ่มจากมีก้อนที่เต้านมด้านซ้ายมีอาการเจ็บตรงก้อนลักษณะก้อนแข็งครับเลยพาไปตรวจพบว่าเป็นมะเร็งแต่คุณแม่เป็นเชื้อชนิด Her 2 ครับ เป็นเชื้อชนิดที่มีโอกาสเป็นน้อยตอนนี้รักษาอยู่ครับผ่าเต้านมออกให้คีโมครบแล้ว แ... ดูเพิ่มเติม',
#  'มะเร็งเต้านม และ มะเร็งปอด',
#  'Pichamon Gift ถ้าอ่านจิตตกแน่',
#  'Mayuree Panmanee',
#  'กุ๊กไก่ ฮาร์ดคอร์',
#  'Niphaporn Sreeluwat',
#  'น้ำหวาน หวาน',
#  'ต่อมทอลซิลขวาโตเหมือน อมลูกอมอยู่1เม็ด แต่ไม่เจ็บค่ะ ใช่อาการเบื้องต้นมั้ยค่ะ',
#  'เป็นมะเร็งรังไข่รักษามาแล้ว1ปี ตอนนี้ค่ามะเร็งไม่มีแล้วจ้าาา  แต่ติดตามอาการทุกๆ6เดือน  ก่อนเป็นตรวจเจอถุงน้ำรังไข่ ทำการผ่าตัดเรียบร้อยแล้วนำชิ้นเนื้อไปตรวจเจอมะเร็งรังไข่ระยะที่1',
#  'Rainy NamfonkaPromsith Tapuang',
#  'ตา=มะเร็งปอดยาย=มะเร็งปอดลุง=มะเร็งหลอดอาหารพ่อ = มะเร็งกระเพาะอาหาร ทุกคนเสียชีวิตหมดแล้ว เราเลยต้องออกกำลังกายบ่อยๆ เพราะกลัวเป็น ขอให้ทุกคนแข็งแรง ใครป่วยก็หายไวๆนะคะ',
#  'เอาไว้ดูแลตนเอง',
#  'อันนี้ไม่รู้จริงๆนะคะ เราไม่สามารถตรวจครั้งแรก แล้ว หาเชื้อมะเร็งเลย หรือ ตรวจเพื่อหาเชื้อมะเร็งโดยตรง ได้เลยหรอคะ เพราะส่วนมาก คือ ตรวจเจอที คือระยะสุดท้ายแล้ว …... ดูเพิ่มเติม',
#  'Non Rthachoknititanadun',
#  'ขอบคุณค่ะ',
#  'มีก้อนเนื้อในคอค่ะ',
#  "Mini May'Sumisa อดกินไอติมหมีล้าวว 555",
#  'Bii Nilawan',
#  '#มะเร็งโพรงจมูก อาการ: น้ำมูกไหลเหมือนคนเป็นภูมิแพ้ จนต่อมน้ำเหลืองบวม เลยไปตรวจแล้วพบมะเร็งในกระโหลกศีรษะ ระยะที่ 3',
#  'น่าร้ากกกกก',
#  'Aor Natkritta Apipong',
#  'Raywat Kumm',
#  'ผมเป็น มะเร็งไทรอย ออกการไม่มีเลยแค่กินเยอะแต่ไม่อ้วน ตรวจสุขภาพประจำปีที่โรงงานหมอบอกเหมือนจะเป็นไทรอย  เลยไปตรวจตามสิทธิประกันสังคม ตรวจตามอาการ อัลตร้าซาวด์ที่คอ เจาะคอ แล้วไม่เจอมะเร็ง หมอถามจะผ่าไหม ผมเลยตัดสินใจผ่า เลยรู้ว่าเป็นมะเร็งไทรอย (ช๊อกไ... ดูเพิ่มเติม',
#  'ดีครับดีมากคนไม่รู้จะได้รู้แล้วระวัง',
#  'Iff O-o',
#  'พ่อเป็น มะเร็งปอด ระยะ4 (ยังไม่แพร่กระจาย)แบบไม่รู้ตัว ว่าเกิดจากสาเหตุอะไร  อาการแรกๆ คือไอ ไอติดต่อกัน ไอปรนเลือด ตรวจหลายสิ่งหลายอย่างไม่พบ จนอัตตราซาว หมอจึงบอก พบก้อนเนื้อในปอดขนาดเล็ก หมอยังไม่วินิจฉัยว่ามะเร็งหรืออะไร จนหมอเอาชิ้นเนื้อไปตรวจ พบเ... ดูเพิ่มเติม',
#  'Koy Panadda',
#  'เคยเป็นมะเร็งไตระยะที่1ค่ะ',
#  'ปิยนุช คงสมRoon Kongsomอ่านๆ',
#  'เป็นมะเร็งเต้านมค่ะ ตอนนี้อยู่เนเธอร์แลนด์ ตอนไปตรวจคือคลำเจอก้อนที่เต้านมด้านซ้าย  แต่ก้อนนี้คลำเจอนานสองสามปีแล้ว เลยคิดว่าไม่ได้เป็นมะเร็ง แค่ก้อนเนื้อ  แต่ไปตรวจเอาให้สบายใจ  ผลตรวจออกมาว่าเป็นก้อนเนื้อ ไม่ใช่มะเร็ง  แต่ต้องติดตามผลทุกหกเดือน หมอเล... ดูเพิ่มเติม',
#  'ผมจะต้องทำยังไงครับ อยากแชร์ แต่มันยาวมากเลยนะ จะเขียนเป็นตอนดีมะ',
#  'สัญชาตญาณนักล่าได้ผุดกำเนิด 555',
#  'Naruebed Downtak',
#  'Iam KüNg Ampare Diamond เค้าชอบวิธีคิดและการเลี้ยงลูกของบ้านนี้มากๆอ่ะ ที่สำคัญสามีน่ารักมากเข้าใจภรรยาที่สุด',
#  'Chutima Numjaroenvuthi',
#  'ใช่ค่ะหายใจไม่อิ่มหายใจสั้นลง',
#  'สุขภาพดี ไม่มีขาย ถ้าอยากได้ ต้องทำเอง ลดหวาน มันเค็ม ดื่มน้ำ เยอะๆ อย่างน้อย แปดแก้ว แต่ในเฉพาะ บุคคล หาคนที่มีภาวะ เป็นไต ระยะสุดท้าย ต้องงดน้ำ ปรึกษาแพทย์นะคะ สิ่งเล็กๆที่เรียกว่ารัก',
#  'Moonoi JT',
#  'Boat Natchapon',
#  'Suriya Viraivoung',
#  'เคสคุณแม่ เริ่มจากมีก้อนนูนออกมาคลำเจอที่อวัยวะเพศค่ะ หาหมอคนที่1 บอกว่าเป็นต่อมบาร์โธลินอักเสบ ตอนแรกคุณหมอบอกทำหัตถการเจาะน้ำก็น่าจะจบ ปรากฎว่าข้างในก็มีก้อนเนื้อเหลืออยู่อีกลึกๆ ต้องผ่าตัดใหญ่ ตอนแรกเจาะถุงน้ำไปตรวจยังไม่เจออะไร คุณหมอบอกไม่ใช่เนื้อร้าย ยังไม่ต้องรีบเอาออกก็ได้ แต่คุณแม่เริ่มเจ็บเพราะ พอเจาะถุงน้ำ น้ำมันไหลไม่หยุด จึงเปลี่ยนคุณหมอ คุณหมอบอกถ้าไม่เอาออกก็จะเจ็บอยู่แบบนี้ จึงนัดผ่าตัดเอาก้อนเนื้อออก ผ่าออกมาก้อนเท่าไข่เป็ด หมอคว้านเอาออกให้ได้มากที่สุด แผลไม่เหวอะวะ คุณหมอก็ยังบอกว่าไม่น่าใช่เนื้อร้าย แต่พอเอาเนื้อไปตรวจพบว่าเจอมะเร็ง คุณหมอบอกตอนแรกเนื้อที่เอาไปตรวจอาจไม่เยอะพอ ก็รักษาต่อทั้งCT MRI คุณหมอพิจารณาให้เอาต่อมน้ำเหลืองที่ขาหนีบทั้งสองข้างออก ตรวจยังไม่ลามไปต่อมน้ำเหลือง เป็นมะเร็งชนิด adenoid cystic carcinoma ตำแหน่งต่อมบาร์โธลิน ระยะ2 ก็นัดฉายแสงต่อ 33ครั้ง ตอนนี้ฉายแสงจบ คุณหมอนัดfollow up ระวังการกลับมาเป็นซ้ำ ถามคุณหมอว่าเราจะรู้หรือระวังได้ยังไง คุณหมอบอกว่าก็ตรวจภายใน สังเกตตัวเองถ้าคลำเจอก้อน หรือมีอาการผิดปกติ ผื่นคันแปลกๆ ก็มาให้คุณหมอตรวจ ส่วนเรื่องสาเหตุค่อนข้างหลากหลายมาก หมอคงไม่สามารถตอบได้นอกจากตัวเจ้าของ แต่อายุมากขึ้นความเสี่ยงในการเป็นก็มีมากขึ้นค่ะ',
#  'กรณีหมอวิเคราะห์ผิดพลาดก็อันตรายมากครับเกือบทำให้ยายผมเสียชีวิตเพราะ ยายมีอาการปวดท้องอย่างหนัก แต่พอไปหาหมอคนแรกบอกว่าแค่อาหารเป็นพิษ แต่พอไปอีกคลินิกนึง หมอบอกไส้ติ่งกำลังจะแตกแล้วรีบส่งตัวไปผ่าทันที ดีนะที่รอดมาได้ครับ',
#  'Yada Lakhonjun',
#  'Patthana Pupey',
#  'Jang Tippawan Phopan',
#  'ณัฐวุฒิ ใจเย็น',
#  'ขอบคุณค่ะ คุณหมอ',
#  'Boonbaramee Tanyasiri',
#  'Ae Suchanya ในตู้เย็นของชเอมมีไรอยู่บ้าง',
#  'จำใว้จะได้ไม่ต้องคอยถาม Tidarat Mivv',
#  'Eyesliz Jamjuree',
#  'บุญนภา ภูพนานุสรณ์ แม่มาอ่าน',
#  'ตอนอายุ 33ปีตั้งแต่ต้นๆปี มีเลือดออกจากจมูก ทั้งๆที่ตั้งแต่เกิดมาไม่เคยเป็นมีอาการมาหลายครั้งเลย ทานวิตามินC แต่อาการก็ยังมีเรื่อยๆจนถึงปลายปี มีอาการหายใจไม่ออกที่จมูกข้างซ้าย ทานยาก็ไม่หาย จึงไปรักษาที่โรงพยาบาล ทานยาก็ไม่หายยังหายใจไม่ได้ แพทย์นัดตรวจอีกครั้ง พบเห็นก้อนในจมูก สั่งตรวจตัดชิ้นเนื้อไปตรวจในวันจันทร์ วันพุธมีอาการดวงตาข้างซ้ายมองภาพไม่เห็น เลยไปโรงพยาบาลด่วน แพทย์สั่งส่งตรวจ CT Scanผลเป็นมะเร็งในโพรงจมูกวันจันทร์ไปโรงพยาบาลจุฬาลงกรณ์พบแพทย์ หู คอ จมูกวันอังคารตรวจกระดูกเพิ่มวันพูธพบอาจารย์หมอชวลิตวันพฤหัสบดีเคมีบำบัดเข็มที่ 1วันอาทิตย์ ดวงตามองเห็นปกติรักษาต่อเนื่อง จนหายเป็นปกติค่ะ.',
#  'Weerapat Wongchai',
#  'แม่เป็นมะเร็งเนื้อเยื่อบุผิว (Epitheloid sarcoma).ประมาณต้นปี 58 มีก้อนเล็กๆ ขึ้นใกล้ๆ ข้อมือด้านขวา ... ดูเพิ่มเติม',
#  'ชีวิตใหม่ ในโลกกว้าง',
#  'สุทิน อิ่มอ่วม Jesada Jsd มาอ่าน',
#  'Nat Zen',
#  'Thanat Phetsri พ่อมาอ่านค่ะ',
#  'Paradorn Somboonlakkana ',
#  'Nomiwus Seangaroonwitchu',
#  'Watsamon Chanpeng',
#  'Supreedee P Pantan',
#  'Nuknick Pantila',
#  'คุณแม่เริ่มมีอาการท้องผูกค่ะตอนอายุ75ค่ะต่อมาเริ่มปวดหลังตอนตีสามพอหน้าหนาวปวดมากแม้ยาพาราเอาไม่อยู่เรยต้องมาเอ็กซเรย์ แร้วct scan พบว่าเป็นมะเร็งกระดูกก้นกบค่ะ',
#  'Nack  Ore-Mine',
#  'Kitti Timrod Nut Kamonchanok Mintra Bangwiroonrak',
#  'สังเกตุที่ "เล็บ"ความผิดปกติของอวัยวะภายในร่างกาย แสดงออกที่เล็บถ้าการงอกใหม่ มีตำหนิ บกพร่อง เปนแนวมาเลย  แสดงว่ามี อวัยวะภายในบกพร่อง/ชำรุด หนึ่งในนั้นอาจมีสาเหตุจากเกิดมะเร็งที่อวัยวะนั้นๆ... ดูเพิ่มเติม',
#  'เป็น  #มะเร็งหลังโพรงจมูก  ตรวจเจอตอนอายุ 30 ค่ะพ่อเป็นมะเร็งปอดค่ะ(มะเร็งกินกระดูกซี่โครงขวาที่3ลงสันหลังลงขา เดินไม่ได้ ไม่มีแรง) ตรวจเจอระยะรุกราม',
#  'ของเรากินข้าวไม่ได้ผอมไปตรวจค้ะเด่วนี้รักษาครบแล้วค้ะมะเยื่อบุเจริญผิดที่ค่ะตัดยกชุดคีโม6ฉายแสง25ฝังแร่3ค่ะไม่แพ้ค่ะกินนมทางการแพทยกับไข่ขาวผงผลไม้ผงผักผงจ้าจบการรักษาคอยติดตามผลตามหมอนัดจ้า',
#  'Charunet Ketsri',
#  'Sawitree Eaidprab',
#  'ตายได้ยังดีเลย',
#  'ความรู้เรื่องโรคมะเร็ง การฉายรังสี วิธีดูแลตนเอง โดย ศ.นพ.ชวลิต เลิศบุษยานุกูล แพทย์รังสีรักษาและมะเร็งวิทยา โรงพยาบาลจุฬาลงกรณ์ สภากาชาดไทย',
#  'คุณแม่มาตรวจพบว่าเป็นมะเร็งเต้านมระยะที่ 3 ตอนที่แม่รู้สึกคลำเจอก้อนที่เต้านมข้างซ้าย แม่นอนคว่ำไม่ได้เพราะรู้สึกเจ็บเต้านม ที่ผ่านมาคุณแม่ไม่เคยไปตรวจสุขภาพเลย พอไปหาหมอเพื่อตรวจหาว่าเป็นมะเร็งเต้านมมั้ยก็คือเป็นมะเร็งจริงๆ แล้วมันก็ลามไปต่อมน้ำเหลืองแล้ว คือรักษายังไงก็ไม่ทันแล้ว แต่คุณแม่กำลังใจดีมาก ผ่าเอาเต้านมข้างซ้ายออก ให้คีโม+ฉายแสงจนครบ อยู่ได้ 7 ปี คุณแม่ก็เสียอย่างสงบที่โรงพยาบาล มาด้วยอาการท้องเสีย+หายใจไม่เต็มปอด ต้องให้ออกซิเจน ตัวเราคลอดลูกได้ 2 วัน คุณแม่ก็เสียค่ะ',
#  'มีใครเป็นมะเร็งหลอดอาหารไหมคะ หนูยังไม่ได้ตรวจค่ะ มีนัดตรวจอีก1เดือนค่ะ แต่กลัวเป็นมากเลยค่ะ ท่านอื่นที่เป็นมีอาการยังไงบ้างหรอคะ หนูุอยากรู้ว่าตรงกันไหมค่ะ',
#  'มะเร็งปอด Thi Cha',
#  'Pongzu Kwane',
#  'Benjaluck Sine Denduang Siraphob Boonvanich',
#  'Preawdao Rattanamathuwong',
#  'She Nam',
#  'เป็นมาแต่เด็ก ตอนนี้จะสี่สิบแล้ว กินอาหารมีประโยชน์ งดเหล้าบุหรี่ ออกกำลัง นอนให้เพียงพอ อยู่ได้อีกนาน',
#  'Ppan Phannapak',
#  'Nath Ampornpipat',
#  'วุฒิภัทร หนูคง',
#  'Nida Tajai',
#  'มะเร็งลำไส้ค่ะ..ท้องอืดสลับท้องเสียถ่ายมีมูกปน น้ำหนักลดทั้งที่กินปกติ ผ่าตัดก้อนเนื้อออกใส่ถุงถ่ายหน้าท้องแร้วตอนนี้เพิ่งให้คีโมเสด12ครั้ง ทรมานแต่ต้องผ่านมันไปให้ได้ค่ะ',
#  'เห็นด้วยค่ะ',
#  'Pung Sutida',
#  'ตรงข้ามกับเด็กบ้านนี้เลยคะ ชอบมากอยากกินมาก นางกินไม่ถึง 10 คำ ทุกสิ่งไม่เคยหมดแม้แต่ไอติม 1 ถ้วย หุหุ',
#  'การวัดความดันเลือดคือการวัดความดันโดยอาศัยค่าการฟังเสียงชีพจร',
#  'อยากจะบอกว่ารักได้แต่ร้องเยเย้ เยเยเย เย่เยเย๊ เย่เย่เย่',
#  'คุณแม่เป็นมะเร็งไขกระดูกชนิด MM (multiple myeloma มะเร็งพลาสมาเซลล์)ตอนอายุ 49 ปีที่ตรวจพบเพราะ มีอาการปวดกระดูก และท้องผูก ปวด แน่นท้อง ตรวจเลือดไม่พบค่ามะเร็ง แต่พบแคลเซียมในเลือดสูง เลยต้องส่งตรวจไขกระดูกเลยเจอว่าเป็นมะเร็ง ค่ะและคุณแม่มีมะเร็งเต้านมอีกอย่าง เจอเพราะคุณหมอที่ตรวจสุขภาพประจำปีที่ทำงาน คลำพบก้อนที่บริเวณหน้าอกเลยแนะนำให้ไปตรวจ หลังจากตรวจสุขภาพประจำปีที่ทำงานได้1เดือนคุณแม่ก็มีอาการที่กล่าวมาข้างต้นจึงทำให้ตรวจเจอไขกระดูกชนิด MM ก่อนมะเร็งเต้านมค่ะคุณแม่เป็นมะเร็งไขกระดูกชนิด MM (multiple myeloma มะเร็งพลาสมาเซลล์)ตอนอายุ 49 ปีที่ตรวจพบเพราะ มีอาการปวดกระดูก และท้องผูก ปวด แน่นท้อง ตรวจเลือดไม่พบค่ามะเร็ง แต่พบแคลเซียมในเลือดสูง เลยต้องส่งตรวจไขกระดูกเลยเจอว่าเป็นมะเร็ง ค่ะ... ดูเพิ่มเติม',
#  'ขอบคุณมากค่ะที่นำมาแบ่งปัน',
#  'เป็นอยู่ในบางครั้งคงต้องไปตรวจบ้างแล้ว',
#  'Makoto Eiei',
#  'พ่อเป็นมะเร็งตับคะ สาเหตุเริ่มจากเป็นไวรัสตับอักเสษบี อาการตาเหลือง ตรวจเจอมะเร็งตับได้ 3 วัน ลามไปท่อน้ำดีและท่อน้ำดีแตก อยู่ได้อีก 4 วัน พ่อก็จากไปคะ พ่อชอบกินเหล้าคะตั้งแต่หนุ่มๆ',
#  'นี่แหละเป็นสิ่งที่น่ากลัวน้ำตาลที่สะสมเราไม่รู้ว่าสะสมอยู่ส่วนไหนสะสมมากเท่าไหร่นะ โจนาธาน เป็นห่วงนายมากเลย กลับเร็วๆนะ',
#  'น่ารักมากๆๆ',
#  'Poopae Chattarika Jaihao ปันปันอ้วนไปแล้ว5555',
#  'หัวใจจะเต้นเร็วเวลาตื่นเต้น ตกใจ โมโห มือสั่น บางครั้งหายใจไม่ทัน อารมณ์ไม่ปรกติ นี่ก็พยามจะไม่เครียด ใครมีวิธีดีๆแนะนำได้ค่ะ',
#  'Patoo Roonprapant',
#  'ขอบคุณนะค่ะที่แบ่งปันความรู้นะค่ะ',
#  'Pakaporn Auearunchot',
#  'Jingying Chen',
#  '#มะเร็งตับ แม่แฟนอายุ60 ไม่เคยดื่มเหล้า ไม่สูบบุหรี่ น้ำหนักลดแต่ไม่มีอาการอะไร เพราะทุกสัปดาห์ต้องใส่ชุดราตรีออกไปร้องเพลงกับเพื่อน เลยไม่ได้คิดถึงเรื่องเจ็บป่วย คิดว่าแม่คุมอาหาร แต่ต้นเดือน ต.ค. 2566 จุกท้อง ปวดหลัง กินอะไรก็อ้วกไปหาหมอประเมินว่าเป็... ดูเพิ่มเติม',
#  'ย้อนกลับไปเมื่อ พ.ย. 58 (ตอนนั้นอายุ30ปี) กำลังเดินทางไปทำงานปวดท้องบริเวณด้านขวา (ขณะนั้นอยู่บนเครื่องบิน จึงคิดว่าคงเสียวท้องเหมือนเวลาเล่นสไลด์เดอร์อ่ะค่ะ) แล้วก็ปวดแบบนั้นมาเรื่อยๆไม่ปวดอะไรมากมายแต่ปวดแบบรำคาญ.จนกระทั้ง มี.ค. 59 กำลังแต่งตัวไปทำ... ดูเพิ่มเติม',
#  'Chatchanok Choosri',
#  'ตาเราเป็นมะเร็งกระดูกค่ะ แกปวดหลัง ขา แขนมาก ครอบครัวก็พาก็ไปหาหมอกินยาตามปกติ  มาตรวจเจอว่าเป็นมะเร็งตอนที่ทรุดหนักและเป็นระยะสุดท้ายแล้ว ทุกอย่างเหมือนจะดีออกจากโรงพยาบาลมาได้ประมาณ 1 อาทิตย์ก็ทรุดอีก พอเข้าไปรพ.รอบนี้ คุณตาก็ไม่ไหวบอกว่าขอกลับบ้านไป... ดูเพิ่มเติม',
#  'Pebble Medploi  ดีมากเลยตัว',
#  'เราตรวจเจอ cin III ตอนอายุ 28 ปัจจุบันอายุ 29 ปี ไม่มีอาการอะไรเลย ตรวจเพราะอยากตรวจเฉยๆ ตัดออกไปตอน ธค 65 หมอนัด f/u 6 เดือน ตรวจมา 1 ครั้ง ผลปกติ ครั้ง ที่ 2 เมื่อวาน รอผล 2 สัปดาห์ นัดครั้งต่อไปทุก 1 ปี จนตลอดชีวิต ตอนไปตามนัดเราตรวจ co-test และก็ h... ดูเพิ่มเติม',
#  'พ่อปวดฟัน กินอาหารไม่ได้ กลืนลำบากอาหารเผ็ดที่ชอบก็กินไม่ได้ปวดแสบปวดร้อนไปหมด พอไปหาหมอฟัน หมอฟันไม่รักษาให้บอกให้รีบไปรพ.ใหญ่ พ่อก็โกรธแล้วไม่ไป ... ดูเพิ่มเติม',
#  'แม่ผมปกติหมดทุกอย่าง ตอนสาวๆแม่เคยเจอก้อนซีดที่นมข้างขวาครับแล้วก็ผ่าออกก็ไม่เป็นอะไร จนมาอายุ50กว่า แม่ก็ลองคลำๆที่นมข้างขวา เจอก้อนเล็กๆครับ จับไปไม่เจ็บไม่อะไร โดยที่ไม่มีอาการเจ็บป่วยหรืออะไรเลย ตอนนั้นเลยตัดสินใจไปตรวจชิ้นเนื้อ สรุปเป็นเนื้อร้ายครับ โชคดีที่เป็นระยะแรก รักษาโดยการฉายแสง30กว่าครั้งผมไม่แน่ใจจำนวนครั้ง+กินยาครับ แล้วก็ผ่าชิ้นเนื้อร้ายนั้นออก ไม่ได้ผ่าออกทั้งเต้า แล้วก็ไม่ได้ทำคีโม หลังจากนั้นหมอนัดตรวจเรื่อยๆ ปัจจุบันแข็งแรงดีครับ ขอบคุณครับ',
#  'Nattida Lida',
#  'Phatchareeporn Khetkhan',
#  'วันนี้ประมาณนี้น่าคราบ',
#  'โน๊ต ครับ ไว้เป็นความรู้',
#  'Pakorn Buasongอ้วงงง',
#  'อย่าว่าแต่น้องชูใจเลยค่ะ นี่ก็เป็นเหมือนกัน เมื่อก่อนชอบซื้อไอติมมาแช่ไว้หลายกล่อง กินทีเดียวหมดด้วย น้ำหนักขึ้นสิจะเหลือเรอะ ทุกวันนี้แช่แต่นมกับผลไม้ (เราไม่กินนมและผลไม้แม่กินแทนหมด) น้ำหนักยังไม่ค่อยจะลงเลย',
#  'ขอบคุณมากค่ะ',
#  'Sasithorn Khumgorn น่ารักๆ',
#  'Chanachok Techamongkalaphiwat',
#  'ชอบจังเป็นประโยชน์มากขอแชร์เด้อจ้า',
#  'คุณแม่เป็นมะเร็งที่ลำไส้ใหญ่ส่วนสุดท้ายของทวารหนักค่ะตอนที่ตรวจเจออายุ 63 ปี ระยะที่ 3... ดูเพิ่มเติม',
#  'Num Phasomsup',
#  'ปืน ปรืออ',
#  'พ่อเราตอนอายุ 56 ปี2558 มีอาการเจ็บคอเหมือนทอนซิลอักเสบเป็นอยู่นาน แล้วพบต่อมที่คอและขาหนีบบวม เลยให้พ่อไปหาหมอ หมอให้เจาะและตัดชิ้นเนื้อไปตรวจ พบมะเร็งต่อมน้ำเหลืองระยะแรก แล้วพ่อก็รักษาโดยเคมีบำบัด จนเป็นปกติ ตอนนี้ผ่านมา7ปีแล้วพ่อยังแข็งแรงดีค่ะ กำลังใจดีมีชัยไปกว่าครึ่ง',
#  'มีก้อนที่เต้านมค่ะตอนนี้โรคสงบมา7ปีแล้วค่ะ',
#  'Krit Maniam Ong',
#  'Pailin Kanchanakon',
#  'ที่บ้านมี 2 เคสค่าคุณแม่ปี2553 มะเร็งลำไส้ใหญ่ เจอตอนระยะสุดท้าย(แพร่กระจาย) อาการของแม่แรกๆตัวเหลือง ปวดท้อง ทานอาหารลำบาก ไปตรวจหมอบอกเป็นถุงน้ำดีอักเสบนอนให้ยาฆ่าเชื้อ7วันกลับบ้าน อาการไม่ดีขึ้นเท่าไหร่แม่เลนไปตรวจเพิ่มเติมทำct scan กลืนสี ผลการตรว... ดูเพิ่มเติม',
# ...
#  "Taew S. S'taew",
#  'Jirawat Chatcharkorn',
#  'Ning Nong',
#  'แชร์ปกส.ตัวเองค่ะ เป็นมะเร็งปากมดลูกระยะ3ลามต่อมน้ำเหลืองตรวจเจอช่วงเดือนกุมภาพันธ์2566รักษาจบสิงหาคม2566ฉายแสง25 คีโม5 ฝังแร่3 หลังรักษาจบCtฟังผล31ตุลาคมพบว่าเชื้อยุบหมดแล้วค่ะ ... ดูเพิ่มเติม',
#  'Nuanchan Asawa',
#  'Angkana Jitrukwongsakul',
#  'Taksaporn ชูแจเอาเก้าอี้มาต่อขึ้นไปหยิบไอติมในช่องฟรีซมากินเอง หนูลูกกกก',
#  'Kukkai Supakchaya',
#  'เยี่ยมมากๆค่ะ',
#  'เป็นมะเร็งเต้านม เริ่มแรก คลำเจอก้อนแข็งๆ ที่เต้านม แต่ยังหลอกตัวเองว่าคงเป็นแค่ซีส จนผ่านไป 3 เดือน ก้อนโตขึ้นเรื่อยๆ เลยไปตรวจแมมโมแกรม กับเจาะชิ้นเนื้อ ปรากฎว่าใช่ค่ะ ตัดยกเต้า คีโม กินยา 5 ปี ค่ะ',
#  'Nantawat Chockkanapitak',
#  'แม่หนูอายุ38ค่ะ มีลูกเยอะ เคยทำแท้ง2ครั้ง มีลูกที่ไม่ได้ทำ3คน พี่ชาย1คน หนูเป็นแฝดชายหญิงค่ะ แม่เสพยา ตั้งแต่ท้องแรก หน้าจะอายุ20ค่ะ จนวันสุดท้ายที่เสีย เลิกได้เลิกนะคะ ตรวจได้ก็ตรวจเลยนะคะ',
#  '2 วันต่อเเท่งนี่เยอะเกินไปค่ะ ที่บ้านให้กินเป็นบางโอกาส เท่านั้น ไม่อยากให้เค้าคิดว่าของหวานคือสิ่งที่ต้องทานหลังอาหาร ให้เป็น treat พิเศษๆ ดีกว่า',
#  'พี่ชายเป็นมะเร็งตับ ชอบกินไก่ย่างวิเชียร ลูกชิ้นปิ้ง หมูกระทะ ผัดกะเพราหมูเนื้อติดมันเยอะๆ สูบบุหรี่นิดหน่อย ตอนที่เริ่มผิดปกติ คือ แน่นท้องง่าย  อยู่ๆ ก็เริ่มไอ ไอตลอด ไออยู่เกือบเดือน ไปฉีดยาก็ไม่ดีขึ้น เลยตรวจวัณโรค ดันไปเจอก้อนขนาด7cm จากนั้นก็กินไ... ดูเพิ่มเติม',
#  'อายุ 25 ปี (ปัจจุบัน 29 ปี)ป่วยมะเร็งกระดูกOsteosarcoma ที่ข้อไหล่แขนซ้าย ระยะที่2 • เป็นคนที่รักสุขภาพ เลือกกิน ไม่เจ็บป่วยอะไรง่ายๆเลย ออกกำลังกาย ชอบเล่นกีฬา ... ดูเพิ่มเติม',
#  'Parama Parama อาหารการกินสำคัญออกกำลังดูแลตัวเองด้วยนะ',
#  'ทานง่ายก็ดีนะคะ แม่ไม่ต้องปวดหัว อาจจะต้องเลือกอาหารหน่อย',
#  'แม่เราอาการเริ่มแรกเบื่ออาหารมากๆกินอะไรไม่อร่อย ไม่ค่อยมีแรง ปกติแม่เราไม่ค่อยแข็งแรง อยู่ๆวันนึงคลำเจอก้อนเล็กๆที่หน้าอกกลิ้งได้ไปหามาเขาบอกไม่ใช่เนื้อร้ายอะไร และแม่ก็มีปอดติดเชื้อหลังจากนั้นก็นอนโรงบาลไม่กี่วันหาย แต่อาการก็ไม่ค่อยดีเลยไปหาหมออีกรอบพบเจอเนื้อในปอดแต่ไม่รู้ว่าเนื้อดีเนื้อร้ายจนไปเจาะปอดก็พบมะเร็ง ของแม่เราเสียตั้งแต่ช่วงเจาะปอดเลยยังไม่ได้รักษามะเร็ง แม่เป็นมะเร็งระยะที่3',
#  'ดีครับ ขอบคุณมากๆ ที่ผลิตสื่อ ที่เข้าใจง่าย ออกมา ครับ',
#  'Wattanapong Ketsuwan',
#  'แบบนี้ล่ะครับ',
#  "Ploiiry'z Ploy",
#  'Tarn Preeratcha',
#  'Natchapong Phayungvong',
#  'Joy Jirawan ลองทำตามนะจ๊ะคุณแม่',
#  'Grace Surada',
#  'ขอบคุณมากค่ะ ขออนุญาตแชร์นะคะ',
#  'Na ChaiWat',
#  'ตอนแม่เป็น มีแค่อาการปวดขา  ขาปวดเป็นลูกจากนั้นมีไข้แล้ว ทรุดเลยจากขา มะเร็งกระดูก... ดูเพิ่มเติม',
#  'Jittima Watsawang',
#  'ขอบคุณ\u200bทุกๆท่านเลยค่ะ',
#  'Suphachai Ruamkarn เฮียย',
#  'เคยเป็นค่ะนานๆทีคิดว่าเพราะนอนไม่ค่อยหลับ',
#  'เรื่องโรคนั้าในหูไม่เท่าก้น ร้กษาย้งง้ยให้หายช่วยบอกหน่อยได้มั้ย  บ้านหมุน มาก',
#  "A'Jurairux Sakulrung",
#  'แม่เราป่วยเป็นมะเร็งปากมดลูก ไม่มีอาการใดๆ เพราะไปตรวจคัดกรองของ รพสต. รู้เร็ว รักษาเร็ว ใช้เวลาไม่ถึง 1 ปี ตอนนี้คุยหายแล้วค่ะ มีติดตามอาการตามหมอนัด ถ้าใครมีรายชื่อตรวจตาม รพสต. อยากให้ตรวจนะคะ มันดีมากๆ',
#  'รออ่านนะ',
#  'Mung Korn',
#  'Wasinee Trepetch',
#  'Maruko Jane',
#  'คุณแม่บุญธรรม มีศักดิ์เป็นป้าของเราเองสายตรง ไม่มีใครเป็น #มะเร็งเต้านมหรือมะเร็งอื่นๆ เลย อาการเริ่มแรกไม่มีอะไรเลย ท่านคลำเจอก้อนใต้รักแร้ เลยไปตรวจเมมโมแกรม หมอเจาะชิ้นเนื้อไปตรวจผลออกมา ท๊าดา เป็นมะเร็งเต้านม แต่ท่านแกร่งมาก และเก่งมากๆ ให้เคมี 2 ครอส ครอสละ 15 ครั้ง ไม่ได้ฉายแสง ท่านทานผัก ผลไม้ เน้นปลานึ่ง ทุกเช้าปั่นน้ำผักกิน ท่านออกกำลังกายโดยการเล่นไพ่ 5555 แม่อยู่ได้ 8 ปีกว่า ผลตรวจสุดท้ายมะเร็งหายเกือบ 90% แต่ท่านก็มาตรอมใจเพราะเสียป๊าบุญธรรมของเราไปด้วยมะเร็งตับ ป๊าก็ตรวจเจอรักษาแค่ 3 เดือนก็เสีย แต่แม่เสียตามกันเวลาห่างกันแค่ 8 เดือน ส่วนป๊านอนน้อยทำงานหนัก สูบบุหรี่จัด ไม่ดื่มเหล้าสุรา ที่สำคัญชอบทานเครื่องดื่มชูกำลังวันละ 3-4 ขวดได้',
#  'Aunge YN',
#  'สวัสดีค่ะ ตอนนั้นอายุ27ปีืเป็นมะเร็งปากมดลูกระยะแรกค่ะ อาการเจ็บปวดใดๆ ไม่มีเลย อาการมีแค่เลือดออกตอนมีเพศสัมพันธุ์ พอทิ้งไว้สักคืนก็หายปกติ  เป็นอยู่ประมาน3-4เดือนเลยไปหาหมอ หมอก็วินิจฉัยอาจจะเป็นปากมดลูกอักเสบให้ยามากิน2อาทิตย์แล้วไปพบหมอดูอาการอีกที พอไปพบหมอรอบนี้ก็ยังไม่หาย เลยได้คลิปชิ้นเนื้อไปตรวจ สรุปมีเชื้อมะเร็ง ทางคุณหมอเลยทำเรื่องส่งตัวไปโรงบาลวชิระ เดินเรื่องคุยกับคุณหมอ ไม่ถึง2เดือน คุณหมอเร่งคิวให้ผ่าตัดเอามดลูกออกเพราะกลัวมะเร็งจะล่าม แต่ก็โชคดีที่รู้เร็วเลยรักษาง่ายด้วยค่ะ ตัดออกก็คือจบ  ผลการผ่าตัดเป็นไปได้ด้วยดี อาจด้วยว่าเราอายุยังน้อย ด้วยค่ะร่างกายเลยพักฝืนได้ดี หลังจากนั้นก็ไป ซาวด์เช็คทุกๆ3เดือน เพราะคุณหมอบอกว่า ไม่ได้หาย100%ต้องดูแลเรื่องการกิน คอยเช็คอัพ ตลอด เพราะอาจจะกลับมาเป็นอีกได้ค่ะ',
#  'ท่านใดพอทราบไหมคะว่าเราสามารถทำประกันอะไรไว้ได้ ในขณะที่ยังตรวจไม่เจอแต่รู้สึกมีความเสี่ยง ￼',
#  'Netima Tungsatitchai',
#  'Jiramet Charoensetthakij',
#  'เราเป็น มะเร็งกระดูก Osteosarcoma อาการตอนแรกคือ เวลาออกกำลังกายหนักๆ จะปวดเข่าซ้าย แค่พัก3-4 วันก้หาย ถ้ากลับไปออกกำลังกายอีกก้เป็นอีก จนไปx-ray พบเป็นก้อนเนื้อ เส้นผ่านศูนย์กลาง8 ซม.  ให้คีโม ก่อนผ่า3 คอร์ส หลังผ่า2 คอร์ส  คอร์สละ3 วัน  ฉายแสง 30 ครั... ดูเพิ่มเติม',
#  'น้องชายผมเป็นมะเร็งที่ลิ้น ชอบสูบบุหรี่ กินของย่าง ของดอง และทานโปรตีนเยอะ จนเป็นแผลที่ลิ้นเริ่มลุกลาม ตอนนี้เสียชีวิตครับ',
#  'คุณแม่เป็นมะเร็งเต้านมเจอระยะที่ 1 เป็นตัวอันตราย HER2 คุณแม่นัดตัดเต้านมทิ้งทันทีและให้คีโม อาการที่เหมือนการเตือนคือ อายุเกือบ 70 แต่มีอาการคัดเต้านม ผ่านมา 8 ปีแล้วค่ะ และคุณพ่อเป็นมะเร็งต่อมลูกหมาก ฉายแสงครบ ผ่านมา 6 ปีแล้วค่ะ **ทั้งคู่รู้ว่าเป็นมะ... ดูเพิ่มเติม',
#  'ขอบคุณมากจ๊ะจ๋อ',
#  'ขอแชร์คะ',
#  '***ของแม่เราที่เสียไปจากมะเร็งนะคะ***มะเร็งตับอ่อน แม่เป็นแบบเนื้อเยื่อข้างในตับอ่อน**หมอราชวิถีแจ้งว่ามะเร็งที่แม่เริ่มเป็นคือมะเร็งตับอ่อนโอกาสที่คนจะเป็นแทบหนึ่งในแสนแต่แม่เป็นหนักจนเป็นมะเร็งเนื้อเยื่อข้างในตับอ่อนซึ่งแทบจะหนึ่งในล้าน... ดูเพิ่มเติม',
#  'ชีวิน เจนสมบูรณ์',
#  'ชัดเจนคอนทรัคชั่น ทิพย์พินิจ',
#  'Mam Limwattanayakorn',
#  'คุณปู่ปัสสาวะเป็นเลือด ไปพบแพทย์คลำตรวจพบมะเร็งต่อมลูกหมาก รักษาด้วยฮอร์โมนประมาณ10ปี มาMRI follow พบมะเร็งท่อน้ำดีลามไปตับลามทั่วช่องท้องค่ะ-เคสคุณย่า คลำเต้านมรู้สึกเหมือนมีก้อนแข็งๆ รีบไปพบแพทย์ พอคลำแพทย์ก็หน้าเครียดๆแล้ว สั่งทำultrasound mamogram พบเป็นมะเร็งเต้านมระยะ2-เคสลุง มีประวัติเป็นภูมิแพ้ต่อเนื่อง เลือดกำเดาไหลบ่อย ไปพบแพทย์GP ให้ยามากินบ่อยๆไม่หาย ไปเจอหมอEENT ส่องเจอมะเร็งหลังโพรงจมูกค่ะ หลังรักษาโรคสงบได้2ปี กลับมาrecurrent กระจายไปปอดค่ะ-เคสเพื่อน พบว่าตัวเองไม่สบายเป็นไข้บ่อยๆ คลำต่อมน้ำเหลืองโต ลองกินฆ่าเชื้อไม่หาย หมอเจาะพบมะเร็งเต้านมลามไปต่อมน้ำเหลืองค่ะ',
#  'ขออนุญาตแชร์นะครับ ขอบคุณครับ',
#  'Woranit Patkitjaru Puifie San',
#  'จากประสบการณ์ที่แม่เป็นมะเร็งลำไส้ อาหารการกินก็มีส่วน แต่ที่คิดว่าที่สุด คือความเครียดค่ะ แม่เป็นคนที่แข็งแรง แต่เป็นคนคิดมาก มีความเครียดสูง',
#  'พ่อเป็นมะเร็งปอดค่ะ เป็นตั้งแต่เมื่อปี62 อาการคือไอ ไอทั้งวันไอตลอด 5-10นาทีไอที มาจากการสูบบุหรี่ เอกซเรย์เจอฝ้าที่ปอด เลยฉีดสีสแกนใหม่พบก้อนเนื้อ ตัดสินใจตัดออก 1ปีถัดมาไม่ได้มีการกินยาควบคุม ปี63เจอที่ตับ กินยามุงเป้าปีกว่ามะเร็งลามขึ้นสมอง มีอาการป... ดูเพิ่มเติม',
#  'Kani Jung เก็บไว้เป็นความรู้',
#  'Juice Pathomporn',
#  'แชร์และขอบคุณค่ะ',
#  'อภิฤกษ์ นุ่มนวน',
#  'Spike Thapagorn',
#  'พูลศักดิ์ ฐิติเบญจพล',
#  'Mos Chayanut',
#  'Wutthiphong Rawangram',
#  'Pui Chanida',
#  'อยากรู้ว่า เป็นมะเร็ง เจ็บมากไหมคะ ทางนี้ไม่ได้เป็นแต่อยากศึกษาความเจ็บปวดของผู้ที่เคยเป็น',
#  'ช่วงนี้สูงหน่อย',
#  'เศร้าจัง',
#  'คุณพ่อเป็นมะเร็งตับค่ะ ตอนตรวจเจอคือเจอระยะสุดท้ายแล้ว อาการคือปวดท้อง ตัวเหลืองขึ้นเรื่อยๆ ตาขาวเหลือง ท้องเริ่มบวมขึ้นเรื่อยๆเหมือนคนท้อง โตแต่ท้องแต่ร่างกายส่วนอื่นๆผอมลงเลื่อยๆ จุก แน่นเวลาทานข้าว ทำให้ทานข้าวแทบไม่ได้ค่ะ หลัวจากตรวจเจออีก3วัน ท่านก็เสียค่ะคุณแม่เป็นมะเร็งหลายชนิดมาก มะเร็งงเม็ดเลือดขาว มะเร็งกระดูก มะเร็งเต้านม มะเร็งสมอง เจอระยะสุดท้าย ตอนที่เจอคือไม่สามารถตรวจได้แล้วว่าเป็นมะเร็งอะไรก่อนอันแรกเพราะมันกระจายไปทุกๆส่วนของร่างกายแล้ว แม่ไม่ได้ตรวจสุขภาพเลยมาหลายปี อาการคือปวดกระดูก ปวดขาแขนและตามข้อต่อ เดินแทบไม่ไหว ต่อมาเริ่มเป็นผื่นตามตัว จุดค่อนข้างใหญ่ และความสามารถในการใช้ชีวิตประจำวันลดลง หลังจากตรวจพบ แม่มีชีวิตอยู่ได้3เดือนก็เสีย (ตอนแรกหมอบอกว่าอยู่ได้แค่3วัน)คุณพ่อเป็นมะเร็งตับค่ะ ตอนตรวจเจอคือเจอระยะสุดท้ายแล้ว อาการคือปวดท้อง ตัวเหลืองขึ้นเรื่อยๆ ตาขาวเหลือง ท้องเริ่มบวมขึ้นเรื่อยๆเหมือนคนท้อง โตแต่ท้องแต่ร่างกายส่วนอื่นๆผอมลงเลื่อยๆ จุก แน่นเวลาทานข้าว ทำให้ทานข้าวแทบไม่ได้ค่ะ หลัวจากตรวจเจออีก3วัน ท่าน... ดูเพิ่มเติม',
#  'คุณเเม่เป็นมะเร็งรังไข่ค่ะ อาการเริ่มเเรก : จุกเสียด เเน่นท้อง ปวดเกร็งในช่องท้อง ท้องเเข็งเเละป่องขึ้น น้ำหนักลดลง หาหมอโรงพยาบาลประจำอำเภอไม่ได้ตรวจละเอียดมาก คุณหมอวินิจฉัยว่าเป็น โรคกระเพาะ หรือลำไส้อักเสบ กินยาตามอาการมาเป็นเวลาหลายเดือน จนท้องป่อง... ดูเพิ่มเติม',
#  'เจอมะเร็งปากมดลูกระยะ2B ตอนอายุ28ค่ะเริ่มจากการปวดหลังร้าวลงต้นขา และมีตกขาวผิดปกติ มีประจำเดือนนานผิดปกติ จึงไปตรวจภายใน เจอก้อนเนื้อ2cm และตัดชิ้นเนื้อไปตรวจ เจอว่าเปนเนื้อร้าย จากคนที่ไม่เคยตรวจภายในเลยสักครั้ง ช็อคไปเลยค่าาแนวการรักษาของคุณหมอคือ... ดูเพิ่มเติม',
#  'Chanatcha Luethaen',
#  'คุณพ่อเป็นมะเร็งปอด   non small cell ยีนส์ egfr ค่ะ เหตุน่าจะสูบบุหรี่ค่ะ สูบมาเกือบ 30 ปี และเลิกได้มาประมาณ 15 ปี ถึงตรวจเจอค่ะ ',
#  'Lannapa Phantnog เจ เมืองนนท์น๊จ๊.',
#  'ตอนที่เป็นนะคะ น้ำหนักลดลงเร็วมาก ไม่มีแรง ทำงานไม่ไหว',
#  'แฟนเป็นมะเร็งหลังโพรงจมูกระยะ4 ก่อนหน้านั้นประมาณ1ปีมีต่อมน้ำเหลืองโตที่คอ ไปหาหมอที่คลินิกได้ยามากินก้อนยุบลงนิดหน่อย แต่เนื่องจากไม่เจ็บจึงไม่ได้รักษาต่อ ภายในระยะเวลา1ปีมีเลือดกำเดาไหลบ้างบางครั้งถามหมอที่คลินิกก็บอกว่าน่าจะเป็นเพราะเส้นเลือดฝอยแตกจ... ดูเพิ่มเติม',
#  'ChananChida Kung Panchaya Mungkornwong',
#  'Ton Khaw',
#  'อ่านๆดูส่วนใหญ่ที่ลุกลามนี่เพราะหมอที่ไปพบคนแรกตรวจไม่ละเอียด เวลาคนฐานะธรรมดาเป็นอะไรไปหาหมอขนาดเสียเงินหลักพันหลายพันนะ ยังรู้สึกเหมือนตรวจผ่านๆ แค่ถามๆให้ยา    พวกบัตรทองไม่ต้องพูดถึงเลย  อยากตรวจละเอียด หรือให้เค้าสนใจจ่ายแพงที่เอกชนอย่างเดียว  เหมือนเราไม่ใช่ญาติอะไรเค้าก็ตรวจๆผ่านๆไป  บ่นมาจากใจถ้าไม่ถูกใจคุณหมอหลายๆท่านขออภัยด้วยครับ',
#  'Nattaon Tumkasem',
#  '#มะเร็ง แชร์ปสก.การรักษามะเร็งปากมดลูกระยะ 2B ตอนอายุ 33 ปี#มะเร็ง แชร์ปสก.การรักษามะเร็งปากมดลูกระยะ 2B ตอนอายุ 33 ปี',
#  'นรา ธิป.',
#  'ชอบกินเนื้อย่าง  ชอบขนมปัง  ของหวาน พวกอาหารขยะต่างๆ   จั้งฟู้ด   อยู่ใกล้คนสูบบุหรี่  แพ้สารเคมีต่างๆ แพ้น้ำหอม   แพ้ฝุ่น........  โดยส่วนใหญ่คือแบคทีเรียไม่ดีในไส้มีเย้อะ และอาหารพวกนี้เอื้อต่อการเติบเตของแบคทีเรียไม่ดี   เมื่อมีแบตทีเรียไม่ดีเย้อะ  ... ดูเพิ่มเติม',
#  'แม่ตรวจเจอเป็นมะเร็งลำใส้ใหญ่ ระยะที่ 3 ค่ะ อาการก่อนตรวจเจอ มีอาการท้องโต แข๊งๆ มีอาการถ่ายไม่ค่อยออก มีริดสีดวงร่วมด้วย และวันนั้นที่ทำให้ไปตรวจโรคเพราะว่าหลานเอากัวชนกับท้องของแม่ แล้วมันก็บวมขึ้นเรื่อยๆ จนไปตรวจที่โรงพยาบาล หมอบอกว่าอาการของแม่คือม... ดูเพิ่มเติมเหนื่อย',
#  'บุญมา ชัยชนะ',
#  'เคยเป็นค่ะ ขอบคุณมากมายค่ะ',
#  'เคยแต่แพ้กาแฟค่ะใจเต้นเร็วมากตัวชาหายใจเหมือนไม่ได้หายใจแทบตายเลยค่ะชีพจรเต้นเร็วมาก',
#  'คุณพ่อ อายุ 65 ปี ตรวจพบมะเร็ง ผ่านไป 2 ปี ตอนนี้หายแล้วค่ะ แต่ยังต้องฟอลโล่อัพทุกๆ 6 เดือนเรื่องมีอยู่ว่า1. พ่อปวดฟัน ไปหาหมอฟัน ที่คลินิคแถวบ้าน รักษาตามอาการ ทานยาแก้ปวดลดอักเสบ ผ่านไป 2 สัปดาห์ อาการปวดฟันหายไป แต่บริเวณใต้ตาข้างๆจมูกมีอาการบวม คลำเห็นเป็นก้อน ไม่เจ็บ แต่ชาๆ 2.ไปหาหมอฟันอีก ที่ รพ ประจำอำเภอ รักษาตามอาการ ได้รับยาแก้ปวด ลดอักเสบ ผ่านไป 2 สัปดาห์ ก้อนนั้นไม่ยุบลงเลย3. รพ ประจำอำเภอ ส่งตัวเข้ารับการรักษาที่ รพ ประจำจังหวัด ก็ยังอยู่ที่แผนกทันตกรรม คุณหมอคาดว่าน่าจะเกิดจากการอักเสบของฟัน ก็เลยส่งผลให้บริเวณไกล้เคียงอักเสบไปด้วย การรักษาก็ยังเหมือนเดิมค่ะ ทานยาแก้ปวด ลดอักเสบอีก 2 สัปดาห์ ก้อนนั้นยุบลง แต่ก็ยังไม่หาย จนเราให้ข้อมูลคุณหมอเพิ่มเติมว่าพ่อเคยใช้ยานัด เป็นไปได้มั้ยว่ามันไม่ได้เกิดจากการปวดฟัน จากการหาข้อมูลของเรา เราคิดสงสัยไปเองว่า อาจจะเป็นการอักเสบของโพรงจมูกหรือไซนัส เพราะอาการค่อนข้างใช่ คุณหมอเองก็สงสัยเช่นนั้น จึงส่งตัวไปที่แผนกหูคอจมูก 4. พบคุณหมอเฉพาะทางหูคอจมูก คุณหมอสั่ง x-ray ก็พบว่ามีก้อนเนื้อบริเวณโพรงจมูกจริง จึงดำเนินการจองคิว CT SCAN ซึ่งต้องรอคิว 2 สัปดาห์ ระหว่างรอก็ทานยาแก้อักเสบต่อไป5. CT SCAN และรอผล 2 สัปดาห์ พอผลออก คุณหมอที่โรงพยาบาลก็แจ้งผู้ป่วยทันทีว่า “คุณพ่อเป็นมะเร็งแน่นอน” และ คุณหมอที่ ร.พ.ประจำจังหวัดไม่สามารถทำการผ่าตัดให้ได้ จึงส่งตัวต่อไปยัง รพ.ศูนย์ ที่อยู่ห่างออกไปอีก 100 กม.6.ไปรักษาต่อที่ รพ.ศูนย์ เหมือนเริ่มการวินิจฉัยใหม่ค่ะ x-ray ใหม่ทั้งหมด และคุณหมอก็สงสัยว่าคุณพ่อจะเป็นมะเร็งโพรงจมูก จึงส่งตัดชิ้นเนื้อไปตรวจ รอผล 2 สัปดาห์7. ผลชิ้นเนื้อออก ปรากฏว่า ไม่มีเชื้อมะเร็ง แต่คุณหมอมั่นใจมากว่ามันคือมะเร็งแน่นอน เพราะก้อนเนื้อมันเริ่มกินเนื้อเยื่อไกล้เคียงเสียหายไปแล้ว จึงนัดตัดชิ้นเนื้อตรวจอีกครั้งใน 1 สัปดาห์ต่อมา และรอผลอีก 2 สัปดาห์8. ผลตรวจชิ้นเนื้อออกแล้ว ใช่ค่ะ มันมีเชื้อมะเร็ง แต่ใม่ใช่มะเร็งโพรงจมูก คุณหมอจึงตรวจละเอียดอีกครั้งและนัดฟังผลอีก 2 สัปดาห์ถัดมา ปรากฎว่าคุณพ่อเป็นมะเร็งต่อมน้ำเหลือง ซึ่งเคสนี้ไม่สามารถผ่าตัดได้ คุณหมอให้ผู้ป่วยและญาติเลือกค่ะว่าจะทำการรักษาที่ไหน ระหว่าง รพ ศูนย์ หรือ รพ มะเร็ง แน่นอนว่าเราเลือก รพ มะเร็งค่ะ ตรงจุด บริการเยี่ยม และความหนาแน่นของผู้ป่วยน้อยกว่า 9. เราดำเนินเรื่องส่งตัวเข้ารับการรักษาที่ รพ มะเร็งวันนั้นเลย คุณพ่อแอดมิดเพื่อรับการรักษาทันที โดยคุณหมอรักษาโดยการให้เคมีบำบัด คุณหมอจะให้ทั้งหมด 16 ครั้ง โดยให้แอดมิด 2 วัน พัก 2 สัปดาห์ ตรวจเลือด พัก 1 สัปดาห์ สลับกันไปแบบนี้จนครบ 16 ครั้ง อาการของคุณพ่อดีขึ้นตามลำดับที่ให้คีโมค่ะ โชคดีที่แพ้ไม่เยอะ ผมร่วงนิดหน่อย และดีที่ท่านแข็งแรงและกำลังใจดีมาก จากวันนั้นผ่านไปเกือบ 2 ปี ตอนนี้ตรวจไม่พบเชื้อมะเร็งแล้วค่ะ ',
#  'เเฟนเราที่เป็นมะเร็งต่อมน้ำเหลือง เริ่มจากมีอาการไอแห้งค่ะ ไอไม่มีเสมหะ ไอเหมือนอาการไอเรื้อรังนานเป็นเดือนไม่มีไข้ แต่เริ่มมีก้อนขนาดฝาน้ำขึ้นตรงไหปลาร้า 2ข้าง เลยพาไปตรวจ รพ.1 เอาชิ้นเนื้อไปตรวจผลชิ้นเนื้อปกติ เลยขอชิ้นเนื้อที่ รพ.1ไปจุ่มหมึก รพ2 ไม่ประมาณ2วันผลตรวจออกเลยค่ะ',
#  'Wanitchaya Puruean',
#  'Nam Watnatee Tanakul Kirin อ่านแล้วจะหลอนกันไหม',
#  'Nuch Njr',
#  'Supat Deechachot',
#  'โพสต์นี้ดี Korry Lee',
#  'Nitaya Gold',
#  'Pollawat Thepkeaw',
#  'เราอายุ 37 ปี เป็นมะเร็งเม็ดเลือดขาว หรือ ลูคีเมีย -ตรวจพบเมื่อ 1 กพ 2560 ',
#  'แม่เป็นมะเร็งถุงน้ำดี ตรวจเจอตอนอายุ 52 ปี แม่เป็นมะเร็งถุงน้ำดี ตรวจเจอตอนอายุ 52 ปี ',
#  'Beth Sarawut Triaukote',
#  'อภิชาติ นครินทร์',
#  'อายุ 33 ปีค่ะ เป็นมะเร็งมดลูก ระยะที่ 3 ค่ะ ตอนนี้รักษาครบคอร์สแล้วเป็นมะเร็งมดลูก ระยะที่ 3 ค่ะ ตอนนี้รักษาครบคอร์สแล้ว',
#  'เราเป็นมะเร็งเต้านมค่ะ ตรวจพบตอนอายุ 25 ปีตอนเจอขั้น 2 ลามต่อม 3 ต่อมค่ะ... ดูเพิ่มเติม',
#  'Khalid Sensom',
#  'ขอบคุณทุกท่านครับ',
#  'Kamolphan Liwrath',
#  'ขอแชร์ต่อนะคะ',
#  'เป็นกำลังใจให้ทุกคนนะครับขอบคุณมีแชร์ประสบการณ์ทุกๆท่านจินตนา สาแช',
#  'Som SophonthaweesubMaliwan BoonkonNida Wongkajit',
#  'ชีวิตประจำวันคือความเครียดกินเบียร์ตลอดและกินมากกว่า 3 ขวดพักผ่อนไม่เพียงพอนอนเยอะแต่หลับน้อยตื่นบ่อยกินไข่เยี่ยวม้าผัดกระเพราทุกวันมีผลทำให้เป็นมะเร็งไทรอยด์หรือไม่เราไม่รู้แต่ชีวิตประจำวันเราเป็นอย่างนี้ อย่างไรถ้ามีอาการเหนื่อย นอนไม่ค่อยหลับ เหงื่อ... ดูเพิ่มเติม',
#  'Aphinya Tangtariyanon',
#  'Sipatausa Mahasaksiri',
#  'ขอบคุณค่ะ ขออนุญาตแชร์เก็บค่ะ',
#  'พ่อเป็นมะเร็งตับ ตอนอายุ 69 กว่าจะตรวจแน่ชัด ก็ระยะสุดท้ายแล้วค่ะ อาการเริ่มแรกไม่มีอะไร ไปหาหมอ รพ แถวบ้านที่ ตจว. บอกแค่เป็นความดันสูงให้กินยาลดควาทดัน อยู่เป็นปีๆพอหลังๆไปนานๆ แกเริ่มปวดท้อง ท้องบวมตัวเริ่มผอมลง ไม่อยากทำอะไรอยากจะนอน ชอบท้องเสีย รพ... ดูเพิ่มเติม',
#  'Tickle Ti',
#  'Orana Chaosoongnoen',
#  'มาอ่าน ละไปตรวจร่างกายกันเถอะItsada-on K Srivatjanapong',
#  'Somruetai Sriamornravadeeอ่านดู',
#  'Namwan Rattanaphon',
#  'ตรวจเป็นมะเร็งไทรอย ตอนอายุ 26 อาการคือมีเสียงแหบเป็นเดือน ก่อนนี้เข้าใจว่าสำลักน้ำลาย ',
#  'Aphiranee SookkeawFramily NititaSophia Linthong Meda Methavee ลองเข้ามาอ่านกันดู เพื่อไว้าังเกตุตัวเองและคสรอบข้างทีืเรารัก',
#  'ตัวบน 133 ล่าง 75 ผลเป็นไง',
#  'Snow Sawanakitiworn จำไว้ดู',
#  'อายุ 17 มะเร็งต่อมน้ำเหลือง lymphoma อาการ ไอเรื้อรังตอนกลางคืนครับ เลือดกำเดาไหล มีก้อนในจมูก ครับอายุ 25 มะเร็ง NETp neuroendocrine carcinoma อาการแรกเลือดกำเดาไหลบ่อย ตรวจเลือดไม่เจอ ไม่มีก้อน หลังตัดชิ้นเนื้อตรวจ พบเป็น small cell จากนั้นก้อนเริ่มมาในจมูกครับ มีอาการโซเดียมต่ำ ระหว่างที่มีก้อนขึ้นมา ดุมากครับ ครอบครัวไม่มีใครเป็นมะเร็งสักคนครับ พฤติกรรมเสี่ยงอาจจะมีบ้างแต่ไม่ค่อยบ่อย เพราะผมเป็นนักกีฬา ต้องคุมอาหารการกินการนอนหลายอย่างครับ',
#  'ซอมบี้ ที่รัก',
#  'ขอให้ทุกๆคนมีสุขภาพแข็งแรงนะคะ',
#  'Aloejo Nicky อนุสร เจนมงคล Siam Chanmongkol',
#  'ขออนุญาตเล่าเคสยายนะคะ ไม่ใช่มะเร็ง แต่เป็นเนื้องอกที่สมอง ส่วนหน้าค่ะ',
#  ...]

# %%
print(len(train_texts))
print(len(train_labels))
# Out:
# 4701
# 4701

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained(bert_model_name)
train_dataset = TextClassificationDataset(train_texts, train_labels, tokenizer, max_length)
val_dataset = TextClassificationDataset(val_texts, val_labels, tokenizer, max_length)
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = BERTClassifier(bert_model_name, num_classes).to(device)
# Out:
# You are using a model of type camembert to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# Some weights of BertModel were not initialized from the model checkpoint at airesearch/wangchanberta-base-att-spm-uncased and are newly initialized: ['embeddings.LayerNorm.bias', 'embeddings.LayerNorm.weight', 'embeddings.position_embeddings.weight', 'embeddings.token_type_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.attention.output.Lay ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
optimizer = AdamW(model.parameters(), lr=learning_rate)
total_steps = len(train_dataloader) * num_epochs
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
for epoch in range(num_epochs):
  print(f"Epoch {epoch + 1}/{num_epochs}")
  train(model, train_dataloader, optimizer, scheduler, device)
  accuracy, report = evaluate(model, val_dataloader, device)
  print(f"Validation Accuracy: {accuracy:.4f}")
  print(report)
# Out:
# Epoch 1/10

# %%
torch.save(model.state_dict(), "bert_classifier.pth")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-350229998996> in <cell line: 1>()
# ----> 1 torch.save(model.state_dict(), "bert_classifier.pth")
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     848     if _use_new_zipfile_serialization:
#     849         with _open_zipfile_writer(f) as opened_zipfile:
# --> 850             _save(
#     851                 obj,
#     852                 opened_zipfile,
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1112                 storage = storage.cpu()
#    1113             # Now that it is on the CPU we can directly copy it into the zip file
# -> 1114             zip_file.write_record(name, storage, num_bytes)
#    1115
#    1116
#
# KeyboardInterrupt:

# %%
# prompt: เรียกใช้ bert_classifier.pth

import os
import torch
from torch import nn
from torch.utils.data import DataLoader, Dataset
from transformers import BertTokenizer, BertModel, AdamW, get_linear_schedule_with_warmup
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
import pandas as pd
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from transformers import AutoTokenizer
bert_model_name = 'airesearch/wangchanberta-base-att-spm-uncased'
num_classes = 3
max_length = 200
batch_size = 16
num_epochs = 4
learning_rate = 2e-5
# Load the saved model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bert_model_name = 'airesearch/wangchanberta-base-att-spm-uncased'
num_classes = 3
model = BERTClassifier(bert_model_name, num_classes).to(device)
model.load_state_dict(torch.load("bert_classifier.pth", map_location=device))
tokenizer = AutoTokenizer.from_pretrained(bert_model_name)

# Example usage:
# text_to_predict = "This is an example text." # Replace with your input
# predicted_sentiment = predict_sentiment(text_to_predict, model, tokenizer, device)
# print(f"Predicted sentiment: {predicted_sentiment}")

class TextClassificationDataset(Dataset):
  def __init__(self, texts, labels, tokenizer, max_length):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length
  def __len__(self):
      return len(self.texts)
  def __getitem__(self, idx):
      text = self.texts[idx]
      label = self.labels[idx]
      encoding = self.tokenizer(text, return_tensors='pt', max_length=self.max_length, padding='max_length', truncation=True)
      return {'input_ids': encoding['input_ids'].flatten(), 'attention_mask': encoding['attention_mask'].flatten(), 'label': torch.tensor(label)}
class BERTClassifier(nn.Module):
  def __init__(self, bert_model_name, num_classes):
        super(BERTClassifier, self).__init__()
        self.bert = BertModel.from_pretrained(bert_model_name)
        self.dropout = nn.Dropout(0.1)
        self.fc = nn.Linear(self.bert.config.hidden_size, num_classes)
  def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        pooled_output = outputs.pooler_output
        x = self.dropout(pooled_output)
        logits = self.fc(x)
        return logits
def predict_sentiment(text, model, tokenizer, device, max_length=128):
    model.eval()
    encoding = tokenizer(text, return_tensors='pt', max_length=max_length, padding='max_length', truncation=True)
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        _, preds = torch.max(outputs, dim=1)
    if preds.item() == 1:
      L = "เล่าประสบการณ์ (tell experience)"
    elif preds.item() == 2:
      L = "คำถาม (Question)"
    else:
      L = "ไม่มีประโยชน์/ไม่สำคัญ (useless/unimportant)"
    return L

df_use = pd.read_csv("/content/data_pre_chi2.csv")
text_use = df_use['comments'].tolist()
labels_use = []
for i in text_use:
  text_to_predict = i # Replace with your input
  predicted_sentiment = predict_sentiment(text_to_predict, model, tokenizer, device)
  labels_use.append(predicted_sentiment)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/546 [00:00<?, ?B/s]
# You are using a model of type camembert to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# model.safetensors:   0%|          | 0.00/423M [00:00<?, ?B/s]
# Some weights of BertModel were not initialized from the model checkpoint at airesearch/wangchanberta-base-att-spm-uncased and are newly initialized: ['embeddings.LayerNorm.bias', 'embeddings.LayerNorm.weight', 'embeddings.position_embeddings.weight', 'embeddings.token_type_embeddings.weight', 'embeddings.word_embeddings.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.0.attention.self.key.bias', 'encoder.layer.0.attention.self.key.weight', 'encoder.layer.0.attention.self.query.bias', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.0.attention.self.value.bias', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.0.output.dense.bias', 'encoder.layer.0.output.dense.weight', 'encoder.layer.1.attention.output.LayerNorm.bias', 'encoder.layer.1.attention.output.LayerNorm.weight', 'encoder.layer.1.attention.output.dense.bias', 'encoder.layer.1.attention.output.dense.weight', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.key.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.1.attention.self.query.weight', 'encoder.layer.1.attention.self.value.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.1.intermediate.dense.bias', 'encoder.layer.1.intermediate.dense.weight', 'encoder.layer.1.output.LayerNorm.bias', 'encoder.layer.1.output.LayerNorm.weight', 'encoder.layer.1.output.dense.bias', 'encoder.layer.1.output.dense.weight', 'encoder.layer.10.attention.output.LayerNorm.bias', 'encoder.layer.10.attention.output.LayerNorm.weight', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.10.attention.output.dense.weight', 'encoder.layer.10.attention.self.key.bias', 'encoder.layer.10.attention.self.key.weight', 'encoder.layer.10.attention.self.query.bias', 'encoder.layer.10.attention.self.query.weight', 'encoder.layer.10.attention.self.value.bias', 'encoder.layer.10.attention.self.value.weight', 'encoder.layer.10.intermediate.dense.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.10.output.LayerNorm.bias', 'encoder.layer.10.output.LayerNorm.weight', 'encoder.layer.10.output.dense.bias', 'encoder.layer.10.output.dense.weight', 'encoder.layer.11.attention.output.LayerNorm.bias', 'encoder.layer.11.attention.output.LayerNorm.weight', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.11.attention.output.dense.weight', 'encoder.layer.11.attention.self.key.bias', 'encoder.layer.11.attention.self.key.weight', 'encoder.layer.11.attention.self.query.bias', 'encoder.layer.11.attention.self.query.weight', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.11.attention.self.value.weight', 'encoder.layer.11.intermediate.dense.bias', 'encoder.layer.11.intermediate.dense.weight', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.11.output.dense.bias', 'encoder.layer.11.output.dense.weight', 'encoder.layer.2.attention.output.LayerNorm.bias', 'encoder.layer.2.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.dense.bias', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.2.attention.self.key.bias', 'encoder.layer.2.attention.self.key.weight', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.2.attention.self.query.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.2.output.LayerNorm.weight', 'encoder.layer.2.output.dense.bias', 'encoder.layer.2.output.dense.weight', 'encoder.layer.3.attention.output.Lay ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-11-8012b236696a>:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("bert_classifier.pth", map_location=device))
# tokenizer_config.json:   0%|          | 0.00/282 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/905k [00:00<?, ?B/s]

# %%
df_use['label'] = labels_use

# %%
LOL= df_use[['comments','label']]

# %%
LOL.to_csv('data_label_chi2.csv', encoding='utf-8-sig',index=False)

# %%
test_text = "ตอบยากนะคะ อาการของโรคต้องให้หมอเป็นคนประเมิน...ส่วนของแม่เรารักษาที่โรงพยาบาลรัฐบาล1เดือนกว่า มีอาการหนักกว่านี้ค่ะ จนถึงจุดที่คุณหมอเข้ามาคุยว่าจะรักษาต่อหรือจะกลับบ้าน รักษาแบบประคับประคอง เรารับรู้อาการของแม่ตลอดว่าแม่ไม่ไหวแล้ว เราเลือกพาแม่กลับบ้าน ท่านอยู่บ้านได้ 11 วันก็จากไปอย่างสงบ ระหว่างอยู่บ้านจะมีทีมรักษาแบบประคับประคองดูแลให้คำปรึกษาตลอดค่ะ"
sentiment = predict_sentiment(test_text, model, tokenizer, device)
print(test_text)
print(f"Predicted sentiment: {sentiment}")
# Out:
# ตอบยากนะคะ อาการของโรคต้องให้หมอเป็นคนประเมิน...ส่วนของแม่เรารักษาที่โรงพยาบาลรัฐบาล1เดือนกว่า มีอาการหนักกว่านี้ค่ะ จนถึงจุดที่คุณหมอเข้ามาคุยว่าจะรักษาต่อหรือจะกลับบ้าน รักษาแบบประคับประคอง เรารับรู้อาการของแม่ตลอดว่าแม่ไม่ไหวแล้ว เราเลือกพาแม่กลับบ้าน ท่านอยู่บ้านได้ 11 วันก็จากไปอย่างสงบ ระหว่างอยู่บ้านจะมีทีมรักษาแบบประคับประคองดูแลให้คำปรึกษาตลอดค่ะ
# Predicted sentiment: เล่าประสบการณ์ (tell experience)
